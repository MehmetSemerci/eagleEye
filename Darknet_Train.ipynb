# %% [markdown]
# <a href="https://colab.research.google.com/github/MehmetSemerci/eagleEye/blob/master/Darknet_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Notebook Title](http://blog.ibanyez.info/download/B20190408T000000071.jpg)

# %% [markdown]
# # How to train YOLOv3 using Darknet on Colab notebook and optimize the VM runtime load times
#
# ## Welcome!
#
# This Colab notebook will show you how to:
#
# * Train a **Yolo v3** model using **Darknet** using the Colab **12GB-RAM GPU**.
# * Turn Colab notebooks into an effective tool to work on real projects. Dealing with the handicap of a runtime that will **blow up every 12 hours** into the space!
#   * Working directly from the files on your computer.
#   * Configure your notebook to install everything you need and start training in about a minute (Tested using 550MB dataset).
#   * Receive your trained weights directly on your computer during the training. While the notebook is training you can check how it is going using your trained weights in your computer.
#
#
# #### This notebook is part of the post [How to train YOLOv3 using Darknet framework and optimize the VM runtime load times](http://blog.ibanyez.info/blogs/coding/20190410-run-a-google-colab-notebook-to-train-yolov3-using-darknet-in/) I encourage you to visit! You will find a deeper explanation about Google Colab, the goods and the limitations of this great tool.
#
#
# ### These are the steps we'll follow:
#
# * Configure Google Drive and map as network  _Drive_.
# * Some utils to help to do some tasks.
# * Configure the pre-requisites on the runtime.
#   * Check the CUDA installation on the runtime VM.
#   * Install cuDNN.
#   * Clone and compile Darknet. We'll use a repo based on [AlexeyAB's Darknet repo](https://github.com/AlexeyAB/darknet/). I applied  some changes to make possible to load files from `/My Drive/` and reduced the number of logs on console to speed up the notebook.
#   * We'll check that everything works great.
# * Explained how to manage your YOLO files on your computer and it will be used transparently from this notebook.
#
# > _**NOTE:** Cells with an annotation **`# Not Necessary cell`**. Can be removed without having any impact. They are only explanatory content._
#
# ### Without further ado, let's start!

# %% [markdown]
# ## STEP 0. Configure runtime to work with GPU
#
# We want to use the **12GB-RAM GPU** hardware acceleration!
#
# Go to **> Menu > Runtime > Configure Runtime Type** And select **GPU** From the **Hardware accelerator** drop down meu

# %% [markdown]
# ## STEP 1. Connect your files to Google Drive
# In order to have your files in your local computer you need to install and configure Google Backup and Sync to keep one folder of your Drive synced with a folder on your computer.
#
# ![schema drive.jpg](http://blog.ibanyez.info/download/B20190408T000000060.jpg)
#
# 1. Create a folder on your Google Drive named _**darknet**_
# 2. Configure the Google Backup and Sync as follows. If you don't speak Spanish, you maybe learn some words! **;)**
# ![Sync Drive.jpg](http://blog.ibanyez.info/download/B20190408T000000063.jpg)
#
# **After this step you'll have a folder called _darknet_ in your local computer. This folder is where you will work with files on your computer**
#
# > _**TIP** - We need to have a good performance downloading data from Drive to Colab. Having a lot of files in your Drive root folder can slow down the things quite a bit. It's a good practice working with Colab to move all your root folder files into a folder_

# %% [markdown]
# ## STEP 2. Connect the Colab notebook to Google Drive
#
# Now we're gonna map your Google Drive folder. This first step is the only one that will require your manual interaction every time you run your notebook.
#
# * Execute the following cell _(Click on Play button or press CTRL + ENTER)_ and click on the link to authorize your notebook to access to your Google Drive.
# * Paste the code Google will give to you and push `enter`

# %%
# This cell imports the drive library and mounts your Google Drive as a VM local drive. You can access to your Drive files 
# using this path "/content/gdrive/My Drive/"

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Congratulations! Now you can access to your local computer folder directly from here!
#
# Check it out!

# %%
# Not Necessary cell
# List the content of your local computer folder 
# !ls -la "/content/gdrive/My Drive/darknet"
# Out:
# total 202
# drwx------ 2 root root   4096 Jul 11 07:52 backup
# drwx------ 2 root root   4096 Jul 11 07:26 bin
# drwx------ 2 root root   4096 Jul 11 07:40 cfg
# drwx------ 2 root root   4096 Jul 11 07:40 check
# -rw------- 1 root root      3 Jul 11 07:54 coco.names
# drwx------ 2 root root   4096 Jul 11 07:01 cuDNN
# drwx------ 2 root root   4096 Aug 26 19:22 detect
# drwx------ 2 root root   4096 Jul 11 07:40 img
# -rw------- 1 root root    220 Jul 11 08:06 obj.data
# -rw------- 1 root root      3 Jul 11 07:54 obj.names
# -rw------- 1 root root      0 Jul 11 07:54 test.txt
# -rw------- 1 root root 171755 Aug 27 10:45 train.txt
# drwx------ 2 root root   4096 Jul 11 07:41 weights

# %% [markdown]
# ## STEP 2. Check CUDA release version
#
# Nvidia CUDA is pre-installed on Colab notebooks. Now we'll check the version installed.
#
# > _**BE AWARE:** Maybe some time from the time I'm writing these lines (April 9th, 2019)  the CUDA version is upgraded on Colab and you should download another version of the cuDNN in the next step. Now is release 10.0 and we are using cuDNN (cudnn-10.0-linux-x64-v7.5.0.56.tgz) accordingly_

# %%
# This cell can be commented once you checked the current CUDA version
# CUDA: Let's check that Nvidia CUDA is already pre-installed and which version is it. In some time from now maybe you 
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %% [markdown]
# ## STEP 3. Install cuDNN according to the current CUDA version
# Now, you need to download cuDNN from Nvidia web site. You'll need to sign up on the site.
#
# * Download cuDNN from [Nvidia website](https://developer.nvidia.com/cudnn)
#
#   * Right now, because we have _**CUDA 10.0**_ preinstalled in Colab runtime, you need download [cuDNN v7.5.0.56 for CUDA v10.0](https://developer.nvidia.com/compute/machine-learning/cudnn/secure/v7.5.0.56/prod/10.0_20190219/cudnn-10.0-linux-x64-v7.5.0.56.tgz) - the file is cudnn-10.0-linux-x64-v7.5.0.56.tgz
#
# * On your local computer, create a folder named _**cuDNN**_ in your local folder _**darknet**_. Copy the _**tgz**_ file there

# %%
# We're unzipping the cuDNN files from your Drive folder directly to the VM CUDA folders
# !tar -xzvf gdrive/My\ Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h

# Now we check the version we already installed. Can comment this line on future runs
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %% [markdown]
# ## STEP 4. Installing Darknet
# Great!! We have all the necessary to start working with Darknet.
#
# This notebook works with a slightly modified version of darknet, which is based on the [AlexeyAB Darknet repo](https://github.com/AlexeyAB/darknet/)
# The changes applied to the original repo are:
# * Allowing to use spaces on the darknet configuration files _**obj.data**_. Necessary to work with Google Drive directly.
# * Removing some logs on every epoch. The original repo write more logs than the Colab notebook can sync. This creates a long queue during the training. This version only shows the results after every iteration.
#
# You can take a look to the code at the [github repo](https://github.com/kriyeng/darknet/)
#
# > _**TRICK**: Because we want to run the notebook fast every time we will compile darknet only the first time we run this notebook. Then, we'll save the compiled version to your drive. For the future executions we'll copy the compiled one instead of compiling again._
#
#
# **Here comes our first trick to speed up the runtime load time**
#
# * The first time we will:
#   * Clone and compile the darknet project.
#   * Copy the compiled version to our Google Drive Floder
#
# * The next times, instead of compiling it again on every runtime load, we'll copy the compiled version to our VM machine!
#
# When compiling the first time, your output last line has to be something like this:
#
# `g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU (...)`

# %% [markdown]
# ## STEP 4-A. Cloning and compiling Darkent. ONLY NEEDS TO BE RUN ON THE FIRST EXECUTION!!
# In this step we'll clone the darkent repo and compile it.
# * Clone Repo
# * Compile Darknet
# * Copy compiled version to Drive
#
# When compiling ends, your output last line has to be something like this:
#
# _`g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU (...)_`

# %%
# Leave this code uncommented on the very first run of your notebook or if you ever need to recompile darknet again.
# Comment this code on the future runs.
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet

# Check the folder
# !ls

# I have a branch where I have done the changes commented above
# !git checkout feature/google-colab

#Compile Darknet
# !make

#Copies the Darknet compiled version to Google drive
# !cp ./darknet /content/gdrive/My\ Drive/darknet/bin/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 9.98 MiB | 11.01 MiB/s, done.
# Resolving deltas: 100% (6766/6766), done.
# /content/darknet
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  CMakeSettings.json      include		     src
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet.py	      LICENSE		     video_yolov3.sh
# build.sh      darknet_video.py	      Makefile
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md
# Branch 'feature/google-colab' set up to track remote branch 'feature/google-colab' from 'origin'.
# Switched to a new branch 'feature/google-colab'
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(mat_cv*, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:896:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:228:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:475:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                      ~~^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2016:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2015:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘get_cuda_stream’:
# ./src/dark_cuda.c:120:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# ./src/dark_cuda.c: In function ‘get_cuda_memcpy_stream’:
# ./src/dark_cuda.c:141:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# ./src/dark_cuda.c: In function ‘cudnn_handle’:
# ./src/dark_cuda.c:161:23: warning: unused variable ‘status’ [-Wunused-variable]
#          cudnnStatus_t status = cudnnSetStream(handle[i], get_cuda_stream());
#                        ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:951:28: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                      size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                             ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# ./src/maxpool_layer.c: In function ‘cudnn_maxpool_setup’:
# ./src/maxpool_layer.c:26:19: warning: variable ‘maxpool_status’ set but not used [-Wunused-but-set-variable]
#      cudnnStatus_t maxpool_status;
#                    ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:511:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:335:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:333:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:332:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:331:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:330:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:329:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:328:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:874:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1008:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1007:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:58:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:65:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:92:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:101:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %% [markdown]
# ## STEP 4-B. Copying the compiled version of Darknet from Drive. UNCOMMENT AFTER FIRST EXECUTION
# Copy the darknet compiled version from drive to the VM.
# * Make the local darknet folder
# * Copy the darknet file
# * Set execution permissions

# %%
# Uncomment after the first run, when you have a copy of compiled darkent in your Google Drive

# Makes a dir for darknet and move there
#!mkdir darknet
#%cd darknet

# Copy the Darkent compiled version to the VM local drive
#!cp /content/gdrive/My\ Drive/darknet/bin/darknet ./darknet

# Set execution permissions to Darknet
#!chmod +x ./darknet

# %% [markdown]
# ## STEP 5. Runtime configuration finished!
# Let's chek it out!
#
# If you are running this notebook for the first time, you can run the following cells in order to check if everything goes as expected!

# %% [markdown]
# ## Some Utils
# Let's add some utils that maybe can be useful.
#
# These utils are:
# * imgShow() - Will help us to show an image in the remote VM
# * download() - Will allow you to get some file from your notebook in case you need to
# * upload() - You can upload files to your current folder on the remote VM.
#
# Thanks to [Ivan Goncharov](https://twitter.com/Ivangrov) for these helpers!

# %%
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
# Not necessary cell
# Get yolov3 weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2019-08-20 16:11:27--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  64.8MB/s    in 3.9s
#
# 2019-08-20 16:11:31 (60.7 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# **NOTE:** The following test only will work when the darknet is compiled in the runtime. This demo uses some data from the original darknet folders. For your Object detection projects, you'll have these necessary files on your local folder.

# %%
# Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# !./darknet detect /content/gdrive/My\ Drive/darknet/cfg/yolov3-voc.cfg /content/gdrive/My\ Drive/darknet/backup/yolov3-voc_last.weights /content/gdrive/My\ Drive/darknet/img/image5.jpg -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
#   13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   17 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   20 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   23 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   26 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   29 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   32 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   35 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    52 x  52 x 256   ->    26 x  26 x 512 1.595 BF
#   38 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   39 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   42 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   45 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   48 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   51 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   54 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   57 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   60 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    26 x  26 x 512   ->    13 x  13 x1024 1.595 BF
#   63 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   64 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   67 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   70 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   73 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   76 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   77 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   78 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   79 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   80 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   81 conv     18  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x  18 0.006 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 256 0.044 BF
#   85 upsample            2x    13 x  13 x 256   ->    26 x  26 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    26 x  26 x 768   ->    26 x  26 x 256 0.266 BF
#   88 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   89 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   90 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   91 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   92 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   93 conv     18  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x  18 0.012 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 128 0.044 BF
#   97 upsample            2x    26 x  26 x 128   ->    52 x  52 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    52 x  52 x 384   ->    52 x  52 x 128 0.266 BF
#  100 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  101 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  102 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  103 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  104 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  105 conv     18  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x  18 0.025 BF
#  106 yolo
# Total BFLOPS 65.290
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights...
#  seen 64
# Done!
#  Error: in the file data/coco.names number of names 80 that isn't equal to classes=1 in the file /content/gdrive/My Drive/darknet/cfg/yolov3-voc.cfg
# Cannot load image /content/gdrive/My Drive/darknet/img/image5.jpg
# /content/gdrive/My Drive/darknet/img/image5.jpg: Predicted in 41.076000 milli-seconds.
# Unable to init server: Could not connect: Connection refused
#
# (predictions:1204): Gtk-WARNING **: 14:30:14.372: cannot open display:

# %% [markdown]
# ## If you can see this picture Congratulations!! At this point you have Darknet configured and working!
#
# ![person.jpg](http://blog.ibanyez.info/download/B20190409T000000064.png)

# %% [markdown]
# # PART 2. Training YOLO
#
#  > _**TRICK:** Every time you want to run all your cells automatically you can go to the **> Menu > Runtime > run all**. Maybe you don't want to execute the entire notebook. You can write the following cell where you want to stop the process and uncoment the **`assert False`** command. This will throw an error and will stop to run more cells. Thanks to: [This thread](https://groups.google.com/forum/#!topic/jupyter/ELftSFSiedQ)_

# %%
# don't go beyond here with Run All
#assert False

# %% [markdown]
# ## PART 2. STEP 0. Preparing your data and configuration files
#
# Before going further let's take a look at what configuration files you need to have in your local drive _`darknet`_
#
# ![Yolov3 configuration files cheat sheet.jpg](http://blog.ibanyez.info/download/B20190410T000000072.png)
#
# You can download the cheat sheet [here](http://blog.ibanyez.info/download/B20190410T000000072.png)
#
# If you need deeper explanations on how to prepare your data sets, annotation and deep learning, visit [How to train YOLOv3 using Darknet framework and optimize the VM runtime load times](post link)
#
#
# > **TRICK:** You have to be carefully configuring paths on your config files. _*obj.data*_ file needs to have spaces on the path escaped with _**\**_. Like this: **_/content/gdrive/My\ Drive/darknet/train.txt_**. But, in files **_train.txt_** and **_test.txt_** does not!

# %% [markdown]
# ## PART 2. STEP 1. Loading files to VM local drive
# The network speed between Google Drive and Colab VM can have an impact on your training speed accessing to your dataset images.
#
# You can have 3 possible approaches depending on the size of your dataset.
#
# > _**NOTE:** This step is not necessary for all the configuration files and weights. They can be accessed directly from Google Drive without considerable performance issues. **This step is only for the dataset images and annotations**_
#
# * **Option 1** - You can try  to use directly the files from Google Drive _`img/`_ folder. Depending on your dataset maybe this can be more than good.
# * **Option 2** - Before start training copy your dataset from Google Drive to the local VM filesystem. Maybe can be a good practice to copy as one single tar file and decompress in your VM local _`img/`_ folder
# * **Option 3** - If your dataset is quite big, maybe you can upload to a git repository and clone from here. Usually transfer time between are much better. If you have to decide I have the feeling that bitbucket have better speed transfer times than github, but please, don't take this as confirmed, **I haven't done specific tests on that, I could be wrong!**

# %% [markdown]
# #### PART 2. STEP 1 - Option 1. Using files from Google Drive directly.
# You don't have to do anything here. Your **_train.txt_** should have the correct path:
# * **/content/grdive/My Drive/darknet/img/image001.jpg**. As said before, don't use escaped white space for the paths on _**train.txt**_ and _**test.txt**_

# %% [markdown]
# #### PART 2. STEP 1 - Option 2A. Copying files from Google Drive to VM local filesystem.
# Execute the follow cell to copy your files

# %%
# Copy fils from Google Drive to the VM local filesystem
# !cp -r "/content/gdrive/My Drive/darknet/img" ./img

# %% [markdown]
# #### PART 2. STEP 1 - Option 2B. Copying files zipped from Google Drive to VM local filesystem and unzip locally.
# Execute the follow cell to copy your files and uncompress.
# You can use _*!ls*_ command to esnure what's the correct path you have to configure in your _*train.txt*_ to correctly access to your dataset images

# %%
# Copy your compressed file
#!cp -r "/content/gdrive/My Drive/darknet/img/img.tgz" ./img

# Uncompress zipped file
#!tar -xzvf ./img/img.tgz

# %% [markdown]
# #### PART 2. STEP 1 - Option 3. Clone your image dataset from a git repo. Seems the fastest one.
# Execute the follow cell to clone your dataset repo to VM local filesystem

# %%
# Git clone directly to ./img folder
#!git clone https://[your-repository] ./img

# Check the result - Uncomment when you checked for speed up further runs
#!ls -la ./img

# %% [markdown]
# ## PART 3. Finally, Train your model!
#
# When you execute the following command, your model will start training.
#
# You will have a log line per epoch. On each iteration you will see how your training is going.
#
# > **TRICK: Darknet copies a backup of your trained weights every 100 iterations. As magic, this file will be synced to your local drive on your computer, as well as the backups darknet do every 1000 iterations, saving it on a separate file.**

# %%
# !./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/cfg/yolov3-voc.cfg" "/content/gdrive/My Drive/darknet/weights/darknet53.conv.74" -dont_show
# Out:
# yolov3-voc
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32 0.639 BF
#    1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64 3.407 BF
#    2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32 0.379 BF
#    3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128 3.407 BF
#    6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#    7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#   10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   152 x 152 x 128   ->    76 x  76 x 256 3.407 BF
#   13 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   14 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   17 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   20 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   23 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   26 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   29 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   32 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   35 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    76 x  76 x 256   ->    38 x  38 x 512 3.407 BF
#   38 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   39 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   42 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   45 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   48 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   51 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   54 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   57 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   60 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    38 x  38 x 512   ->    19 x  19 x1024 3.407 BF
#   63 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   64 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   67 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   70 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   73 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   76 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   77 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   78 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   79 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   80 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   81 conv     18  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x  18 0.013 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    19 x  19 x 512   ->    19 x  19 x 256 0.095 BF
#   85 upsample            2x    19 x  19 x 256   ->    38 x  38 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    38 x  38 x 768   ->    38 x  38 x 256 0.568 BF
#   88 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   89 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   90 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   91 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   92 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   93 conv     18  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x  18 0.027 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    38 x  38 x 256   ->    38 x  38 x 128 0.095 BF
#   97 upsample            2x    38 x  38 x 128   ->    76 x  76 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    76 x  76 x 384   ->    76 x  76 x 128 0.568 BF
#  100 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  101 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  102 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  103 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  104 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  105 conv     18  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x  18 0.053 BF
#  106 yolo
# Total BFLOPS 139.465
#  Allocate additional workspace_size = 6.65 MB
# Loading weights from /content/gdrive/My Drive/darknet/weights/darknet53.conv.74...
#  seen 64
# Done!
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
# Resizing
# 896 x 896
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 20.796048 seconds
#
#  1: 4833.574707, 4833.574707 avg loss, 0.000000 rate, 47.690820 seconds, 64 images
# Loaded: 0.000048 seconds
#
#  2: 4826.430664, 4832.860352 avg loss, 0.000000 rate, 49.181410 seconds, 128 images
# Loaded: 0.000069 seconds
#
#  3: 4830.520996, 4832.626465 avg loss, 0.000000 rate, 49.525369 seconds, 192 images
# Loaded: 0.000071 seconds
#
#  4: 4823.971191, 4831.760742 avg loss, 0.000000 rate, 49.765740 seconds, 256 images
# Loaded: 0.000064 seconds
#
#  5: 4833.624023, 4831.947266 avg loss, 0.000000 rate, 49.779037 seconds, 320 images
# Loaded: 0.000067 seconds
#
#  6: 4832.816895, 4832.034180 avg loss, 0.000000 rate, 49.687752 seconds, 384 images
# Loaded: 0.000057 seconds
#
#  7: 4828.818359, 4831.712402 avg loss, 0.000000 rate, 49.782619 seconds, 448 images
# Loaded: 0.000064 seconds
#
#  8: 4831.232422, 4831.664551 avg loss, 0.000000 rate, 49.831709 seconds, 512 images
# Loaded: 0.000075 seconds
#
#  9: 4835.382812, 4832.036133 avg loss, 0.000000 rate, 49.789557 seconds, 576 images
# Loaded: 0.000071 seconds
#
#  10: 4831.696289, 4832.001953 avg loss, 0.000000 rate, 49.708984 seconds, 640 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 5.97 MB
#  CUDA allocate done!
# Loaded: 10.195689 seconds
#
#  11: 2004.325928, 4549.234375 avg loss, 0.000000 rate, 22.395036 seconds, 704 images
# Loaded: 0.000062 seconds
#
#  12: 2005.744873, 4294.885254 avg loss, 0.000000 rate, 22.604129 seconds, 768 images
# Loaded: 0.000058 seconds
#
#  13: 2006.700562, 4066.066895 avg loss, 0.000000 rate, 22.517924 seconds, 832 images
# Loaded: 0.000051 seconds
#
#  14: 2003.907227, 3859.850830 avg loss, 0.000000 rate, 22.470488 seconds, 896 images
# Loaded: 0.000061 seconds
#
#  15: 2006.515015, 3674.517334 avg loss, 0.000000 rate, 22.540824 seconds, 960 images
# Loaded: 0.000050 seconds
#
#  16: 2004.346558, 3507.500244 avg loss, 0.000000 rate, 22.528884 seconds, 1024 images
# Loaded: 0.000051 seconds
#
#  17: 2004.405518, 3357.190674 avg loss, 0.000000 rate, 22.491854 seconds, 1088 images
# Loaded: 0.000060 seconds
#
#  18: 2001.994873, 3221.671143 avg loss, 0.000000 rate, 22.477249 seconds, 1152 images
# Loaded: 0.000065 seconds
#
#  19: 2005.671631, 3100.071289 avg loss, 0.000000 rate, 22.467628 seconds, 1216 images
# Loaded: 0.000067 seconds
#
#  20: 2003.634155, 2990.427490 avg loss, 0.000000 rate, 22.448175 seconds, 1280 images
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 10.236510 seconds
#
#  21: 4488.502441, 3140.234863 avg loss, 0.000000 rate, 46.798213 seconds, 1344 images
# Loaded: 0.000079 seconds
#
#  22: 4492.429688, 3275.454346 avg loss, 0.000000 rate, 47.145484 seconds, 1408 images
# Loaded: 0.000063 seconds
#
#  23: 4489.685059, 3396.877441 avg loss, 0.000000 rate, 47.115797 seconds, 1472 images
# Loaded: 0.000059 seconds
#
#  24: 4489.029297, 3506.092529 avg loss, 0.000000 rate, 47.036643 seconds, 1536 images
# Loaded: 0.000091 seconds
#
#  25: 4485.463867, 3604.029785 avg loss, 0.000000 rate, 47.073696 seconds, 1600 images
# Loaded: 0.000061 seconds
#
#  26: 4488.324219, 3692.459229 avg loss, 0.000000 rate, 47.037028 seconds, 1664 images
# Loaded: 0.000070 seconds
#
#  27: 4484.229004, 3771.636230 avg loss, 0.000000 rate, 46.994944 seconds, 1728 images
# Loaded: 0.000071 seconds
#
#  28: 4480.258789, 3842.498535 avg loss, 0.000000 rate, 47.052072 seconds, 1792 images
# Loaded: 0.000063 seconds
#
#  29: 4479.569336, 3906.205566 avg loss, 0.000000 rate, 47.033818 seconds, 1856 images
# Loaded: 0.000087 seconds
#
#  30: 4476.299316, 3963.214844 avg loss, 0.000000 rate, 47.025258 seconds, 1920 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 5.33 MB
#  CUDA allocate done!
# Loaded: 7.668925 seconds
#
#  31: 1782.086914, 3745.102051 avg loss, 0.000000 rate, 20.152196 seconds, 1984 images
# Loaded: 0.000056 seconds
#
#  32: 1780.123901, 3548.604248 avg loss, 0.000000 rate, 20.283976 seconds, 2048 images
# Loaded: 0.000060 seconds
#
#  33: 1779.991211, 3371.742920 avg loss, 0.000000 rate, 20.231971 seconds, 2112 images
# Loaded: 0.000063 seconds
#
#  34: 1775.385254, 3212.107178 avg loss, 0.000000 rate, 20.281004 seconds, 2176 images
# Loaded: 0.000061 seconds
#
#  35: 1772.047485, 3068.101318 avg loss, 0.000000 rate, 20.246656 seconds, 2240 images
# Loaded: 0.000051 seconds
#
#  36: 1770.638184, 2938.354980 avg loss, 0.000000 rate, 20.259189 seconds, 2304 images
# Loaded: 0.000075 seconds
#
#  37: 1767.533569, 2821.272949 avg loss, 0.000000 rate, 20.233008 seconds, 2368 images
# Loaded: 0.000047 seconds
#
#  38: 1764.981689, 2715.643799 avg loss, 0.000000 rate, 20.232834 seconds, 2432 images
# Loaded: 0.000055 seconds
#
#  39: 1760.253418, 2620.104736 avg loss, 0.000000 rate, 20.220264 seconds, 2496 images
# Loaded: 0.000069 seconds
#
#  40: 1759.744629, 2534.068848 avg loss, 0.000000 rate, 20.255487 seconds, 2560 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 4.72 MB
#  CUDA allocate done!
# Loaded: 6.636508 seconds
#
#  41: 1556.136353, 2436.275635 avg loss, 0.000000 rate, 17.250226 seconds, 2624 images
# Loaded: 0.000064 seconds
#
#  42: 1553.499512, 2347.998047 avg loss, 0.000000 rate, 17.335652 seconds, 2688 images
# Loaded: 0.000066 seconds
#
#  43: 1551.344238, 2268.332764 avg loss, 0.000000 rate, 17.302874 seconds, 2752 images
# Loaded: 0.000083 seconds
#
#  44: 1545.866699, 2196.086182 avg loss, 0.000000 rate, 17.302203 seconds, 2816 images
# Loaded: 0.000057 seconds
#
#  45: 1544.361206, 2130.913574 avg loss, 0.000000 rate, 17.364989 seconds, 2880 images
# Loaded: 0.000055 seconds
#
#  46: 1540.036011, 2071.825928 avg loss, 0.000000 rate, 17.334072 seconds, 2944 images
# Loaded: 0.000074 seconds
#
#  47: 1535.317017, 2018.175049 avg loss, 0.000000 rate, 17.333680 seconds, 3008 images
# Loaded: 0.000049 seconds
#
#  48: 1529.027832, 1969.260376 avg loss, 0.000000 rate, 17.302844 seconds, 3072 images
# Loaded: 0.000053 seconds
#
#  49: 1523.801270, 1924.714478 avg loss, 0.000000 rate, 17.326925 seconds, 3136 images
# Loaded: 0.000083 seconds
#
#  50: 1519.843872, 1884.227417 avg loss, 0.000000 rate, 17.330634 seconds, 3200 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 5.33 MB
#  CUDA allocate done!
# Loaded: 8.428263 seconds
#
#  51: 1708.364380, 1866.641113 avg loss, 0.000000 rate, 20.195661 seconds, 3264 images
# Loaded: 0.000069 seconds
#
#  52: 1700.622925, 1850.039307 avg loss, 0.000000 rate, 20.250396 seconds, 3328 images
# Loaded: 0.000066 seconds
#
#  53: 1693.935913, 1834.428955 avg loss, 0.000000 rate, 20.229440 seconds, 3392 images
# Loaded: 0.000070 seconds
#
#  54: 1686.191040, 1819.605225 avg loss, 0.000000 rate, 20.275671 seconds, 3456 images
# Loaded: 0.000072 seconds
#
#  55: 1676.024414, 1805.247192 avg loss, 0.000000 rate, 20.220427 seconds, 3520 images
# Loaded: 0.000074 seconds
#
#  56: 1669.578003, 1791.680298 avg loss, 0.000000 rate, 20.226003 seconds, 3584 images
# Loaded: 0.000058 seconds
#
#  57: 1659.427246, 1778.454956 avg loss, 0.000000 rate, 20.221905 seconds, 3648 images
# Loaded: 0.000069 seconds
#
#  58: 1650.970947, 1765.706543 avg loss, 0.000000 rate, 20.247388 seconds, 3712 images
# Loaded: 0.000048 seconds
#
#  59: 1639.846924, 1753.120605 avg loss, 0.000000 rate, 20.233791 seconds, 3776 images
# Loaded: 0.000067 seconds
#
#  60: 1628.682739, 1740.676758 avg loss, 0.000000 rate, 20.245478 seconds, 3840 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 5.33 MB
#  CUDA allocate done!
# Loaded: 4.893489 seconds
#
#  61: 1616.379761, 1728.247070 avg loss, 0.000000 rate, 20.173467 seconds, 3904 images
# Loaded: 0.000051 seconds
#
#  62: 1605.197510, 1715.942139 avg loss, 0.000000 rate, 20.269826 seconds, 3968 images
# Loaded: 0.000073 seconds
#
#  63: 1591.915894, 1703.539551 avg loss, 0.000000 rate, 20.249220 seconds, 4032 images
# Loaded: 0.000054 seconds
#
#  64: 1576.062134, 1690.791748 avg loss, 0.000000 rate, 20.237989 seconds, 4096 images
# Loaded: 0.000070 seconds
#
#  65: 1565.121460, 1678.224731 avg loss, 0.000000 rate, 20.248847 seconds, 4160 images
# Loaded: 0.000052 seconds
#
#  66: 1547.760864, 1665.178345 avg loss, 0.000000 rate, 20.234595 seconds, 4224 images
# Loaded: 0.000065 seconds
#
#  67: 1528.422729, 1651.502808 avg loss, 0.000000 rate, 20.192437 seconds, 4288 images
# Loaded: 0.000060 seconds
#
#  68: 1512.670654, 1637.619629 avg loss, 0.000000 rate, 20.201087 seconds, 4352 images
# Loaded: 0.000068 seconds
#
#  69: 1495.033936, 1623.361084 avg loss, 0.000000 rate, 20.208985 seconds, 4416 images
# Loaded: 0.000055 seconds
#
#  70: 1477.112671, 1608.736206 avg loss, 0.000000 rate, 20.260046 seconds, 4480 images
# Resizing
# 768 x 768
#  try to allocate additional workspace_size = 10.62 MB
#  CUDA allocate done!
# Loaded: 1.284234 seconds
#
#  71: 2898.619141, 1737.724487 avg loss, 0.000000 rate, 37.653616 seconds, 4544 images
# Loaded: 0.000073 seconds
#
#  72: 2851.878662, 1849.139893 avg loss, 0.000000 rate, 37.784539 seconds, 4608 images
# Loaded: 0.000089 seconds
#
#  73: 2800.468262, 1944.272705 avg loss, 0.000000 rate, 37.792435 seconds, 4672 images
# Loaded: 0.000078 seconds
#
#  74: 2746.471191, 2024.492554 avg loss, 0.000000 rate, 37.790409 seconds, 4736 images
# Loaded: 0.000073 seconds
#
#  75: 2687.528809, 2090.796143 avg loss, 0.000000 rate, 37.820831 seconds, 4800 images
# Loaded: 0.000067 seconds
#
#  76: 2619.269531, 2143.643555 avg loss, 0.000000 rate, 37.789203 seconds, 4864 images
# Loaded: 0.000087 seconds
#
#  77: 2553.186768, 2184.597900 avg loss, 0.000000 rate, 37.735046 seconds, 4928 images
# Loaded: 0.000058 seconds
#
#  78: 2475.413574, 2213.679443 avg loss, 0.000000 rate, 37.733771 seconds, 4992 images
# Loaded: 0.000070 seconds
#
#  79: 2400.120850, 2232.323486 avg loss, 0.000000 rate, 37.717634 seconds, 5056 images
# Loaded: 0.000068 seconds
#
#  80: 2316.834717, 2240.774658 avg loss, 0.000000 rate, 37.716496 seconds, 5120 images
# Resizing
# 704 x 704
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 3.747511 seconds
#
#  81: 1880.075073, 2204.704590 avg loss, 0.000000 rate, 32.649718 seconds, 5184 images
# Loaded: 0.000085 seconds
#
#  82: 1803.848267, 2164.618896 avg loss, 0.000000 rate, 32.952417 seconds, 5248 images
# Loaded: 0.000086 seconds
#
#  83: 1730.247559, 2121.181641 avg loss, 0.000000 rate, 32.927380 seconds, 5312 images
# Loaded: 0.000051 seconds
#
#  84: 1652.030762, 2074.266602 avg loss, 0.000000 rate, 32.815874 seconds, 5376 images
# Loaded: 0.000056 seconds
#
#  85: 1582.379272, 2025.077881 avg loss, 0.000000 rate, 32.873934 seconds, 5440 images
# Loaded: 0.000061 seconds
#
#  86: 1505.002808, 1973.070435 avg loss, 0.000000 rate, 32.816198 seconds, 5504 images
# Loaded: 0.000085 seconds
#
#  87: 1426.161499, 1918.379517 avg loss, 0.000000 rate, 32.774134 seconds, 5568 images
# Loaded: 0.000070 seconds
#
#  88: 1373.162720, 1863.857788 avg loss, 0.000000 rate, 32.859612 seconds, 5632 images
# Loaded: 0.000058 seconds
#
#  89: 1290.786377, 1806.550659 avg loss, 0.000000 rate, 32.810632 seconds, 5696 images
# Loaded: 0.000057 seconds
#
#  90: 1224.425293, 1748.338135 avg loss, 0.000000 rate, 32.839774 seconds, 5760 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 5.33 MB
#  CUDA allocate done!
# Loaded: 3.032711 seconds
#
#  91: 685.588379, 1642.063110 avg loss, 0.000000 rate, 20.132562 seconds, 5824 images
# Loaded: 0.000058 seconds
#
#  92: 646.745483, 1542.531372 avg loss, 0.000000 rate, 20.240715 seconds, 5888 images
# Loaded: 0.000072 seconds
#
#  93: 614.577942, 1449.736084 avg loss, 0.000000 rate, 20.255626 seconds, 5952 images
# Loaded: 0.000059 seconds
#
#  94: 576.177795, 1362.380249 avg loss, 0.000000 rate, 20.246601 seconds, 6016 images
# Loaded: 0.000060 seconds
#
#  95: 542.216858, 1280.363892 avg loss, 0.000000 rate, 20.212643 seconds, 6080 images
# Loaded: 0.000085 seconds
#
#  96: 511.481323, 1203.475586 avg loss, 0.000000 rate, 20.239333 seconds, 6144 images
# Loaded: 0.000056 seconds
#
#  97: 487.595184, 1131.887573 avg loss, 0.000000 rate, 20.202506 seconds, 6208 images
# Loaded: 0.000076 seconds
#
#  98: 455.276398, 1064.226440 avg loss, 0.000000 rate, 20.260305 seconds, 6272 images
# Loaded: 0.000070 seconds
#
#  99: 430.286255, 1000.832397 avg loss, 0.000000 rate, 20.198968 seconds, 6336 images
# Loaded: 0.000061 seconds
#
#  100: 409.722839, 941.721436 avg loss, 0.000000 rate, 20.265158 seconds, 6400 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 4.15 MB
#  CUDA allocate done!
# Loaded: 5.062512 seconds
#
#  101: 304.107574, 877.960022 avg loss, 0.000000 rate, 16.146732 seconds, 6464 images
# Loaded: 0.000069 seconds
#
#  102: 286.827393, 818.846741 avg loss, 0.000000 rate, 16.185168 seconds, 6528 images
# Loaded: 0.000051 seconds
#
#  103: 267.599060, 763.721985 avg loss, 0.000000 rate, 16.193851 seconds, 6592 images
# Loaded: 0.000037 seconds
#
#  104: 254.452301, 712.795044 avg loss, 0.000000 rate, 16.171241 seconds, 6656 images
# Loaded: 0.000137 seconds
#
#  105: 239.966721, 665.512207 avg loss, 0.000000 rate, 16.201205 seconds, 6720 images
# Loaded: 0.000063 seconds
#
#  106: 229.862274, 621.947205 avg loss, 0.000000 rate, 16.120854 seconds, 6784 images
# Loaded: 0.000062 seconds
#
#  107: 219.911438, 581.743652 avg loss, 0.000000 rate, 16.163123 seconds, 6848 images
# Loaded: 0.000054 seconds
#
#  108: 207.010529, 544.270325 avg loss, 0.000000 rate, 16.197158 seconds, 6912 images
# Loaded: 0.000060 seconds
#
#  109: 196.005402, 509.443848 avg loss, 0.000000 rate, 16.140436 seconds, 6976 images
# Loaded: 1.565703 seconds
#
#  110: 182.748199, 476.774292 avg loss, 0.000000 rate, 15.938405 seconds, 7040 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 5.97 MB
#  CUDA allocate done!
# Loaded: 2.009199 seconds
#
#  111: 248.014877, 453.898346 avg loss, 0.000000 rate, 22.342739 seconds, 7104 images
# Loaded: 0.000060 seconds
#
#  112: 240.885406, 432.597046 avg loss, 0.000000 rate, 22.428716 seconds, 7168 images
# Loaded: 0.000060 seconds
#
#  113: 229.219437, 412.259277 avg loss, 0.000000 rate, 22.472845 seconds, 7232 images
# Loaded: 0.000061 seconds
#
#  114: 217.716568, 392.804993 avg loss, 0.000000 rate, 22.465347 seconds, 7296 images
# Loaded: 0.000061 seconds
#
#  115: 203.909775, 373.915466 avg loss, 0.000000 rate, 22.489352 seconds, 7360 images
# Loaded: 0.000089 seconds
#
#  116: 193.475204, 355.871429 avg loss, 0.000000 rate, 22.500345 seconds, 7424 images
# Loaded: 0.000073 seconds
#
#  117: 180.091904, 338.293488 avg loss, 0.000000 rate, 22.440542 seconds, 7488 images
# Loaded: 0.000058 seconds
#
#  118: 176.605423, 322.124695 avg loss, 0.000000 rate, 22.433735 seconds, 7552 images
# Loaded: 0.000041 seconds
#
#  119: 163.049683, 306.217194 avg loss, 0.000000 rate, 22.414204 seconds, 7616 images
# Loaded: 0.000067 seconds
#
#  120: 156.657730, 291.261261 avg loss, 0.000000 rate, 22.462381 seconds, 7680 images
# Resizing
# 672 x 672
#  try to allocate additional workspace_size = 8.13 MB
#  CUDA allocate done!
# Loaded: 1.332878 seconds
#
#  121: 197.873672, 281.922516 avg loss, 0.000000 rate, 29.645227 seconds, 7744 images
# Loaded: 0.000051 seconds
#
#  122: 186.223999, 272.352661 avg loss, 0.000000 rate, 29.899265 seconds, 7808 images
# Loaded: 0.000075 seconds
#
#  123: 176.274002, 262.744781 avg loss, 0.000000 rate, 29.874897 seconds, 7872 images
# Loaded: 0.000068 seconds
#
#  124: 163.153641, 252.785675 avg loss, 0.000000 rate, 29.811612 seconds, 7936 images
# Loaded: 0.000055 seconds
#
#  125: 152.609833, 242.768097 avg loss, 0.000000 rate, 29.784252 seconds, 8000 images
# Loaded: 0.000057 seconds
#
#  126: 141.924332, 232.683716 avg loss, 0.000000 rate, 29.794912 seconds, 8064 images
# Loaded: 0.000048 seconds
#
#  127: 133.337952, 222.749146 avg loss, 0.000000 rate, 29.889878 seconds, 8128 images
# Loaded: 0.000065 seconds
#
#  128: 122.206528, 212.694885 avg loss, 0.000000 rate, 29.799462 seconds, 8192 images
# Loaded: 0.000049 seconds
#
#  129: 117.441948, 203.169586 avg loss, 0.000000 rate, 29.800152 seconds, 8256 images
# Loaded: 0.000053 seconds
#
#  130: 106.020927, 193.454727 avg loss, 0.000000 rate, 29.772272 seconds, 8320 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 4.15 MB
#  CUDA allocate done!
# Loaded: 4.400801 seconds
#
#  131: 53.411522, 179.450409 avg loss, 0.000000 rate, 16.073403 seconds, 8384 images
# Loaded: 0.000053 seconds
#
#  132: 51.886570, 166.694031 avg loss, 0.000000 rate, 16.162156 seconds, 8448 images
# Loaded: 0.000051 seconds
#
#  133: 47.761204, 154.800751 avg loss, 0.000000 rate, 16.151437 seconds, 8512 images
# Loaded: 0.000044 seconds
#
#  134: 44.758488, 143.796524 avg loss, 0.000000 rate, 16.152598 seconds, 8576 images
# Loaded: 0.000064 seconds
#
#  135: 41.814987, 133.598373 avg loss, 0.000000 rate, 16.182387 seconds, 8640 images
# Loaded: 0.000050 seconds
#
#  136: 39.337673, 124.172302 avg loss, 0.000000 rate, 16.111606 seconds, 8704 images
# Loaded: 0.000056 seconds
#
#  137: 40.044083, 115.759483 avg loss, 0.000000 rate, 16.216351 seconds, 8768 images
# Loaded: 0.000041 seconds
#
#  138: 34.999821, 107.683517 avg loss, 0.000000 rate, 16.115303 seconds, 8832 images
# Loaded: 0.000063 seconds
#
#  139: 36.065681, 100.521736 avg loss, 0.000000 rate, 16.205552 seconds, 8896 images
# Loaded: 0.000055 seconds
#
#  140: 30.977156, 93.567276 avg loss, 0.000000 rate, 16.133247 seconds, 8960 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 5.33 MB
#  CUDA allocate done!
# Loaded: 1.406655 seconds
#
#  141: 37.999001, 88.010452 avg loss, 0.000000 rate, 20.029843 seconds, 9024 images
# Loaded: 0.000054 seconds
#
#  142: 34.443848, 82.653793 avg loss, 0.000000 rate, 20.225100 seconds, 9088 images
# Loaded: 0.000065 seconds
#
#  143: 34.116058, 77.800018 avg loss, 0.000000 rate, 20.200790 seconds, 9152 images
# Loaded: 0.000046 seconds
#
#  144: 32.343155, 73.254333 avg loss, 0.000000 rate, 20.203848 seconds, 9216 images
# Loaded: 0.000077 seconds
#
#  145: 32.682007, 69.197098 avg loss, 0.000000 rate, 20.221826 seconds, 9280 images
# Loaded: 0.000072 seconds
#
#  146: 28.835421, 65.160927 avg loss, 0.000000 rate, 20.152917 seconds, 9344 images
# Loaded: 0.000052 seconds
#
#  147: 29.663361, 61.611172 avg loss, 0.000000 rate, 20.182053 seconds, 9408 images
# Loaded: 0.000055 seconds
#
#  148: 27.604500, 58.210503 avg loss, 0.000000 rate, 20.227162 seconds, 9472 images
# Loaded: 0.000046 seconds
#
#  149: 27.786915, 55.168144 avg loss, 0.000000 rate, 20.247619 seconds, 9536 images
# Loaded: 0.000069 seconds
#
#  150: 25.425709, 52.193901 avg loss, 0.000001 rate, 20.202794 seconds, 9600 images
# Resizing
# 640 x 640
#  try to allocate additional workspace_size = 7.37 MB
#  CUDA allocate done!
# Loaded: 2.515106 seconds
#
#  151: 30.446205, 50.019131 avg loss, 0.000001 rate, 26.491994 seconds, 9664 images
# Loaded: 0.000058 seconds
#
#  152: 30.690691, 48.086288 avg loss, 0.000001 rate, 26.747646 seconds, 9728 images
# Loaded: 0.000056 seconds
#
#  153: 28.476130, 46.125271 avg loss, 0.000001 rate, 26.670863 seconds, 9792 images
# Loaded: 0.000045 seconds
#
#  154: 27.797159, 44.292461 avg loss, 0.000001 rate, 26.733237 seconds, 9856 images
# Loaded: 0.000067 seconds
#
#  155: 25.595474, 42.422764 avg loss, 0.000001 rate, 26.703238 seconds, 9920 images
# Loaded: 0.000055 seconds
#
#  156: 24.350357, 40.615524 avg loss, 0.000001 rate, 26.767011 seconds, 9984 images
# Loaded: 0.000060 seconds
#
#  157: 24.484333, 39.002403 avg loss, 0.000001 rate, 26.704785 seconds, 10048 images
# Loaded: 0.000069 seconds
#
#  158: 22.225719, 37.324734 avg loss, 0.000001 rate, 26.704636 seconds, 10112 images
# Loaded: 0.000059 seconds
#
#  159: 20.869171, 35.679176 avg loss, 0.000001 rate, 26.714895 seconds, 10176 images
# Loaded: 0.000055 seconds
#
#  160: 21.640263, 34.275284 avg loss, 0.000001 rate, 26.753359 seconds, 10240 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 6.65 MB
#  CUDA allocate done!
# Loaded: 1.527477 seconds
#
#  161: 20.078516, 32.855606 avg loss, 0.000001 rate, 24.424103 seconds, 10304 images
# Loaded: 0.000041 seconds
#
#  162: 17.424040, 31.312450 avg loss, 0.000001 rate, 24.644986 seconds, 10368 images
# Loaded: 0.000077 seconds
#
#  163: 17.639679, 29.945173 avg loss, 0.000001 rate, 24.604695 seconds, 10432 images
# Loaded: 0.000069 seconds
#
#  164: 17.107998, 28.661455 avg loss, 0.000001 rate, 24.614127 seconds, 10496 images
# Loaded: 0.000062 seconds
#
#  165: 16.587511, 27.454062 avg loss, 0.000001 rate, 24.636991 seconds, 10560 images
# Loaded: 0.000050 seconds
#
#  166: 15.914248, 26.300079 avg loss, 0.000001 rate, 24.620509 seconds, 10624 images
# Loaded: 0.000064 seconds
#
#  167: 16.287327, 25.298803 avg loss, 0.000001 rate, 24.665104 seconds, 10688 images
# Loaded: 0.000056 seconds
#
#  168: 14.660139, 24.234938 avg loss, 0.000001 rate, 24.629483 seconds, 10752 images
# Loaded: 0.000064 seconds
#
#  169: 13.385041, 23.149948 avg loss, 0.000001 rate, 24.594172 seconds, 10816 images
# Loaded: 0.000052 seconds
#
#  170: 13.435369, 22.178490 avg loss, 0.000001 rate, 24.595207 seconds, 10880 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 9.75 MB
#  CUDA allocate done!
# Loaded: 0.000048 seconds
#
#  171: 17.563128, 21.716953 avg loss, 0.000001 rate, 35.458980 seconds, 10944 images
# Loaded: 0.000044 seconds
#
#  172: 16.294085, 21.174667 avg loss, 0.000001 rate, 35.688917 seconds, 11008 images
# Loaded: 0.000063 seconds
#
#  173: 14.465661, 20.503767 avg loss, 0.000001 rate, 35.704088 seconds, 11072 images
# Loaded: 0.000050 seconds
#
#  174: 14.194174, 19.872808 avg loss, 0.000001 rate, 35.794420 seconds, 11136 images
# Loaded: 0.000071 seconds
#
#  175: 15.167354, 19.402264 avg loss, 0.000001 rate, 35.716274 seconds, 11200 images
# Loaded: 0.000065 seconds
#
#  176: 16.638062, 19.125843 avg loss, 0.000001 rate, 35.817433 seconds, 11264 images
# Loaded: 0.000071 seconds
#
#  177: 13.647610, 18.578020 avg loss, 0.000001 rate, 35.688281 seconds, 11328 images
# Loaded: 0.000049 seconds
#
#  178: 10.679500, 17.788168 avg loss, 0.000001 rate, 35.650968 seconds, 11392 images
# Loaded: 0.000086 seconds
#
#  179: 13.328134, 17.342165 avg loss, 0.000001 rate, 35.739003 seconds, 11456 images
# Loaded: 0.000059 seconds
#
#  180: 13.498494, 16.957798 avg loss, 0.000001 rate, 35.746862 seconds, 11520 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 5.97 MB
#  CUDA allocate done!
# Loaded: 1.030620 seconds
#
#  181: 11.940528, 16.456072 avg loss, 0.000001 rate, 22.403863 seconds, 11584 images
# Loaded: 0.000055 seconds
#
#  182: 10.443749, 15.854839 avg loss, 0.000001 rate, 22.466061 seconds, 11648 images
# Loaded: 0.000076 seconds
#
#  183: 10.093972, 15.278752 avg loss, 0.000001 rate, 22.557763 seconds, 11712 images
# Loaded: 0.000054 seconds
#
#  184: 10.923844, 14.843262 avg loss, 0.000001 rate, 22.498901 seconds, 11776 images
# Loaded: 0.000067 seconds
#
#  185: 10.599121, 14.418848 avg loss, 0.000001 rate, 22.459943 seconds, 11840 images
# Loaded: 0.000060 seconds
#
#  186: 7.564825, 13.733446 avg loss, 0.000001 rate, 22.424522 seconds, 11904 images
# Loaded: 0.000059 seconds
#
#  187: 9.442401, 13.304341 avg loss, 0.000001 rate, 22.444570 seconds, 11968 images
# Loaded: 0.000058 seconds
#
#  188: 7.572537, 12.731161 avg loss, 0.000001 rate, 22.404953 seconds, 12032 images
# Loaded: 0.000055 seconds
#
#  189: 9.759658, 12.434011 avg loss, 0.000001 rate, 22.474169 seconds, 12096 images
# Loaded: 0.000041 seconds
#
#  190: 8.275051, 12.018114 avg loss, 0.000001 rate, 22.444044 seconds, 12160 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 4.15 MB
#  CUDA allocate done!
# Loaded: 0.275565 seconds
#
#  191: 9.047640, 11.721066 avg loss, 0.000001 rate, 15.993765 seconds, 12224 images
# Loaded: 0.000040 seconds
#
#  192: 10.280127, 11.576973 avg loss, 0.000001 rate, 16.211401 seconds, 12288 images
# Loaded: 0.000050 seconds
#
#  193: 6.831541, 11.102429 avg loss, 0.000001 rate, 16.135919 seconds, 12352 images
# Loaded: 0.000049 seconds
#
#  194: 9.914287, 10.983615 avg loss, 0.000001 rate, 16.207253 seconds, 12416 images
# Loaded: 0.000073 seconds
#
#  195: 9.219332, 10.807186 avg loss, 0.000001 rate, 16.080726 seconds, 12480 images
# Loaded: 0.000048 seconds
#
#  196: 9.005145, 10.626982 avg loss, 0.000001 rate, 16.207777 seconds, 12544 images
# Loaded: 0.000060 seconds
#
#  197: 8.337293, 10.398013 avg loss, 0.000002 rate, 16.170626 seconds, 12608 images
# Loaded: 0.000058 seconds
#
#  198: 7.900434, 10.148255 avg loss, 0.000002 rate, 16.181247 seconds, 12672 images
# Loaded: 0.000053 seconds
#
#  199: 9.012588, 10.034689 avg loss, 0.000002 rate, 16.136598 seconds, 12736 images
# Loaded: 0.000060 seconds
#
#  200: 7.412764, 9.772496 avg loss, 0.000002 rate, 16.153598 seconds, 12800 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000068 seconds
#
#  201: 9.055453, 9.700792 avg loss, 0.000002 rate, 43.582751 seconds, 12864 images
# Loaded: 0.000054 seconds
#
#  202: 10.469498, 9.777663 avg loss, 0.000002 rate, 43.976777 seconds, 12928 images
# Loaded: 0.000066 seconds
#
#  203: 10.902922, 9.890189 avg loss, 0.000002 rate, 43.927967 seconds, 12992 images
# Loaded: 0.000057 seconds
#
#  204: 9.294982, 9.830668 avg loss, 0.000002 rate, 43.978660 seconds, 13056 images
# Loaded: 0.000066 seconds
#
#  205: 6.940296, 9.541632 avg loss, 0.000002 rate, 43.785245 seconds, 13120 images
# Loaded: 0.000048 seconds
#
#  206: 8.247443, 9.412212 avg loss, 0.000002 rate, 43.846572 seconds, 13184 images
# Loaded: 0.000064 seconds
#
#  207: 8.499165, 9.320908 avg loss, 0.000002 rate, 43.864640 seconds, 13248 images
# Loaded: 0.000044 seconds
#
#  208: 12.231527, 9.611970 avg loss, 0.000002 rate, 43.989728 seconds, 13312 images
# Loaded: 0.000077 seconds
#
#  209: 10.475198, 9.698293 avg loss, 0.000002 rate, 43.876488 seconds, 13376 images
# Loaded: 0.000052 seconds
#
#  210: 10.110065, 9.739470 avg loss, 0.000002 rate, 43.911367 seconds, 13440 images
# Resizing
# 672 x 672
#  try to allocate additional workspace_size = 8.13 MB
#  CUDA allocate done!
# Loaded: 1.259274 seconds
#
#  211: 7.697189, 9.535241 avg loss, 0.000002 rate, 29.546266 seconds, 13504 images
# Loaded: 0.000053 seconds
#
#  212: 7.827415, 9.364458 avg loss, 0.000002 rate, 29.826286 seconds, 13568 images
# Loaded: 0.000059 seconds
#
#  213: 9.393944, 9.367407 avg loss, 0.000002 rate, 29.952972 seconds, 13632 images
# Loaded: 0.000052 seconds
#
#  214: 8.025807, 9.233247 avg loss, 0.000002 rate, 29.936453 seconds, 13696 images
# Loaded: 0.000087 seconds
#
#  215: 8.070757, 9.116998 avg loss, 0.000002 rate, 29.802602 seconds, 13760 images
# Loaded: 0.000058 seconds
#
#  216: 9.290966, 9.134395 avg loss, 0.000002 rate, 29.850615 seconds, 13824 images
# Loaded: 0.000064 seconds
#
#  217: 6.684366, 8.889392 avg loss, 0.000002 rate, 29.802427 seconds, 13888 images
# Loaded: 0.000068 seconds
#
#  218: 7.994976, 8.799951 avg loss, 0.000002 rate, 29.818085 seconds, 13952 images
# Loaded: 0.000064 seconds
#
#  219: 7.425428, 8.662498 avg loss, 0.000002 rate, 29.814125 seconds, 14016 images
# Loaded: 0.000054 seconds
#
#  220: 6.356352, 8.431884 avg loss, 0.000002 rate, 29.789901 seconds, 14080 images
# Resizing
# 704 x 704
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000049 seconds
#
#  221: 8.288472, 8.417542 avg loss, 0.000002 rate, 32.453020 seconds, 14144 images
# Loaded: 0.000126 seconds
#
#  222: 6.394906, 8.215279 avg loss, 0.000002 rate, 32.823017 seconds, 14208 images
# Loaded: 0.000063 seconds
#
#  223: 6.551381, 8.048889 avg loss, 0.000002 rate, 32.740826 seconds, 14272 images
# Loaded: 0.000052 seconds
#
#  224: 7.219775, 7.965978 avg loss, 0.000003 rate, 32.846142 seconds, 14336 images
# Loaded: 0.000062 seconds
#
#  225: 7.366395, 7.906019 avg loss, 0.000003 rate, 32.908174 seconds, 14400 images
# Loaded: 0.000060 seconds
#
#  226: 7.769179, 7.892335 avg loss, 0.000003 rate, 32.791172 seconds, 14464 images
# Loaded: 0.000043 seconds
#
#  227: 9.462940, 8.049396 avg loss, 0.000003 rate, 32.871973 seconds, 14528 images
# Loaded: 0.000070 seconds
#
#  228: 7.468094, 7.991265 avg loss, 0.000003 rate, 32.894397 seconds, 14592 images
# Loaded: 0.000069 seconds
#
#  229: 8.747961, 8.066935 avg loss, 0.000003 rate, 32.834923 seconds, 14656 images
# Loaded: 0.000082 seconds
#
#  230: 9.615193, 8.221761 avg loss, 0.000003 rate, 32.859458 seconds, 14720 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.257141 seconds
#
#  231: 7.122837, 8.111868 avg loss, 0.000003 rate, 40.602069 seconds, 14784 images
# Loaded: 0.000067 seconds
#
#  232: 8.072506, 8.107932 avg loss, 0.000003 rate, 40.973522 seconds, 14848 images
# Loaded: 0.000065 seconds
#
#  233: 6.567523, 7.953891 avg loss, 0.000003 rate, 40.977006 seconds, 14912 images
# Loaded: 0.000061 seconds
#
#  234: 7.972746, 7.955777 avg loss, 0.000003 rate, 41.103078 seconds, 14976 images
# Loaded: 0.000072 seconds
#
#  235: 8.110853, 7.971284 avg loss, 0.000003 rate, 40.982918 seconds, 15040 images
# Loaded: 0.000058 seconds
#
#  236: 6.570637, 7.831220 avg loss, 0.000003 rate, 40.935317 seconds, 15104 images
# Loaded: 0.000051 seconds
#
#  237: 8.599177, 7.908015 avg loss, 0.000003 rate, 41.120221 seconds, 15168 images
# Loaded: 0.000048 seconds
#
#  238: 10.856180, 8.202831 avg loss, 0.000003 rate, 41.048095 seconds, 15232 images
# Loaded: 0.000096 seconds
#
#  239: 8.705103, 8.253058 avg loss, 0.000003 rate, 40.980832 seconds, 15296 images
# Loaded: 0.000057 seconds
#
#  240: 7.763122, 8.204064 avg loss, 0.000003 rate, 40.982988 seconds, 15360 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 9.75 MB
#  CUDA allocate done!
# Loaded: 1.193849 seconds
#
#  241: 7.777757, 8.161433 avg loss, 0.000003 rate, 35.339648 seconds, 15424 images
# Loaded: 0.000049 seconds
#
#  242: 7.416912, 8.086981 avg loss, 0.000003 rate, 35.590428 seconds, 15488 images
# Loaded: 0.000050 seconds
#
#  243: 4.786889, 7.756972 avg loss, 0.000003 rate, 35.483507 seconds, 15552 images
# Loaded: 0.000060 seconds
#
#  244: 9.196157, 7.900890 avg loss, 0.000004 rate, 35.660997 seconds, 15616 images
# Loaded: 0.000077 seconds
#
#  245: 6.426085, 7.753410 avg loss, 0.000004 rate, 35.520182 seconds, 15680 images
# Loaded: 0.000063 seconds
#
#  246: 6.794238, 7.657493 avg loss, 0.000004 rate, 35.504220 seconds, 15744 images
# Loaded: 0.000061 seconds
#
#  247: 7.037596, 7.595503 avg loss, 0.000004 rate, 35.541806 seconds, 15808 images
# Loaded: 0.000050 seconds
#
#  248: 7.527136, 7.588666 avg loss, 0.000004 rate, 35.538002 seconds, 15872 images
# Loaded: 0.000060 seconds
#
#  249: 6.773250, 7.507124 avg loss, 0.000004 rate, 35.550903 seconds, 15936 images
# Loaded: 0.000072 seconds
#
#  250: 7.616910, 7.518103 avg loss, 0.000004 rate, 35.645048 seconds, 16000 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 5.33 MB
#  CUDA allocate done!
# Loaded: 0.574670 seconds
#
#  251: 9.048945, 7.671187 avg loss, 0.000004 rate, 19.927326 seconds, 16064 images
# Loaded: 0.000065 seconds
#
#  252: 8.499894, 7.754058 avg loss, 0.000004 rate, 20.175016 seconds, 16128 images
# Loaded: 0.000056 seconds
#
#  253: 4.956743, 7.474327 avg loss, 0.000004 rate, 20.099517 seconds, 16192 images
# Loaded: 0.000050 seconds
#
#  254: 7.503693, 7.477263 avg loss, 0.000004 rate, 20.123745 seconds, 16256 images
# Loaded: 0.000048 seconds
#
#  255: 6.299487, 7.359486 avg loss, 0.000004 rate, 20.125348 seconds, 16320 images
# Loaded: 0.000052 seconds
#
#  256: 7.043696, 7.327907 avg loss, 0.000004 rate, 20.118825 seconds, 16384 images
# Loaded: 0.000071 seconds
#
#  257: 6.614908, 7.256607 avg loss, 0.000004 rate, 20.128117 seconds, 16448 images
# Loaded: 0.000056 seconds
#
#  258: 8.138589, 7.344805 avg loss, 0.000004 rate, 20.114258 seconds, 16512 images
# Loaded: 0.000075 seconds
#
#  259: 7.719826, 7.382307 avg loss, 0.000004 rate, 20.097297 seconds, 16576 images
# Loaded: 0.000059 seconds
#
#  260: 6.311226, 7.275199 avg loss, 0.000005 rate, 20.152413 seconds, 16640 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000055 seconds
#
#  261: 7.307035, 7.278383 avg loss, 0.000005 rate, 43.472629 seconds, 16704 images
# Loaded: 0.000057 seconds
#
#  262: 6.224373, 7.172982 avg loss, 0.000005 rate, 43.794005 seconds, 16768 images
# Loaded: 0.000073 seconds
#
#  263: 7.446773, 7.200361 avg loss, 0.000005 rate, 43.723188 seconds, 16832 images
# Loaded: 0.000049 seconds
#
#  264: 6.257219, 7.106047 avg loss, 0.000005 rate, 43.849760 seconds, 16896 images
# Loaded: 0.000061 seconds
#
#  265: 7.798894, 7.175332 avg loss, 0.000005 rate, 43.847514 seconds, 16960 images
# Loaded: 0.000042 seconds
#
#  266: 6.395535, 7.097352 avg loss, 0.000005 rate, 43.763393 seconds, 17024 images
# Loaded: 0.000068 seconds
#
#  267: 6.543101, 7.041927 avg loss, 0.000005 rate, 43.735332 seconds, 17088 images
# Loaded: 0.000057 seconds
#
#  268: 5.363316, 6.874066 avg loss, 0.000005 rate, 43.633298 seconds, 17152 images
# Loaded: 0.000065 seconds
#
#  269: 7.107872, 6.897447 avg loss, 0.000005 rate, 43.750851 seconds, 17216 images
# Loaded: 0.000073 seconds
#
#  270: 5.972978, 6.805000 avg loss, 0.000005 rate, 43.695001 seconds, 17280 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 5.97 MB
#  CUDA allocate done!
# Loaded: 0.100454 seconds
#
#  271: 6.599502, 6.784450 avg loss, 0.000005 rate, 22.197416 seconds, 17344 images
# Loaded: 0.000067 seconds
#
#  272: 6.302904, 6.736295 avg loss, 0.000005 rate, 22.344269 seconds, 17408 images
# Loaded: 0.000049 seconds
#
#  273: 8.119247, 6.874590 avg loss, 0.000006 rate, 22.517958 seconds, 17472 images
# Loaded: 0.000050 seconds
#
#  274: 6.330990, 6.820230 avg loss, 0.000006 rate, 22.407105 seconds, 17536 images
# Loaded: 0.000051 seconds
#
#  275: 7.116798, 6.849887 avg loss, 0.000006 rate, 22.415411 seconds, 17600 images
# Loaded: 0.000053 seconds
#
#  276: 6.709661, 6.835865 avg loss, 0.000006 rate, 22.376470 seconds, 17664 images
# Loaded: 0.000054 seconds
#
#  277: 5.515397, 6.703818 avg loss, 0.000006 rate, 22.365071 seconds, 17728 images
# Loaded: 0.000084 seconds
#
#  278: 5.743653, 6.607802 avg loss, 0.000006 rate, 22.343240 seconds, 17792 images
# Loaded: 0.000050 seconds
#
#  279: 7.505162, 6.697538 avg loss, 0.000006 rate, 22.429091 seconds, 17856 images
# Loaded: 0.000065 seconds
#
#  280: 6.686040, 6.696388 avg loss, 0.000006 rate, 22.372327 seconds, 17920 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 4.72 MB
#  CUDA allocate done!
# Loaded: 1.429609 seconds
#
#  281: 7.205857, 6.747335 avg loss, 0.000006 rate, 17.034596 seconds, 17984 images
# Loaded: 0.000049 seconds
#
#  282: 9.674299, 7.040031 avg loss, 0.000006 rate, 17.286157 seconds, 18048 images
# Loaded: 0.000048 seconds
#
#  283: 7.188333, 7.054862 avg loss, 0.000006 rate, 17.275789 seconds, 18112 images
# Loaded: 0.000064 seconds
#
#  284: 6.328347, 6.982210 avg loss, 0.000007 rate, 17.196402 seconds, 18176 images
# Loaded: 0.000062 seconds
#
#  285: 7.804791, 7.064468 avg loss, 0.000007 rate, 17.260070 seconds, 18240 images
# Loaded: 0.000123 seconds
#
#  286: 9.535070, 7.311529 avg loss, 0.000007 rate, 17.272836 seconds, 18304 images
# Loaded: 0.000057 seconds
#
#  287: 5.896118, 7.169988 avg loss, 0.000007 rate, 17.218336 seconds, 18368 images
# Loaded: 0.000064 seconds
#
#  288: 8.905191, 7.343508 avg loss, 0.000007 rate, 17.242153 seconds, 18432 images
# Loaded: 0.000050 seconds
#
#  289: 5.811452, 7.190303 avg loss, 0.000007 rate, 17.212819 seconds, 18496 images
# Loaded: 0.000050 seconds
#
#  290: 6.560701, 7.127343 avg loss, 0.000007 rate, 17.287124 seconds, 18560 images
# Resizing
# 672 x 672
#  try to allocate additional workspace_size = 8.13 MB
#  CUDA allocate done!
# Loaded: 0.128245 seconds
#
#  291: 6.317557, 7.046364 avg loss, 0.000007 rate, 29.433947 seconds, 18624 images
# Loaded: 0.000058 seconds
#
#  292: 5.736655, 6.915393 avg loss, 0.000007 rate, 29.744680 seconds, 18688 images
# Loaded: 0.000057 seconds
#
#  293: 6.168983, 6.840752 avg loss, 0.000007 rate, 29.700027 seconds, 18752 images
# Loaded: 0.000047 seconds
#
#  294: 7.882349, 6.944912 avg loss, 0.000007 rate, 29.749286 seconds, 18816 images
# Loaded: 0.000050 seconds
#
#  295: 6.838628, 6.934284 avg loss, 0.000008 rate, 29.840915 seconds, 18880 images
# Loaded: 0.000066 seconds
#
#  296: 7.131704, 6.954026 avg loss, 0.000008 rate, 29.758809 seconds, 18944 images
# Loaded: 0.000047 seconds
#
#  297: 6.169649, 6.875588 avg loss, 0.000008 rate, 29.734552 seconds, 19008 images
# Loaded: 0.000041 seconds
#
#  298: 6.436920, 6.831721 avg loss, 0.000008 rate, 29.822763 seconds, 19072 images
# Loaded: 0.000058 seconds
#
#  299: 4.663933, 6.614943 avg loss, 0.000008 rate, 29.623208 seconds, 19136 images
# Loaded: 0.000049 seconds
#
#  300: 5.811778, 6.534626 avg loss, 0.000008 rate, 29.745476 seconds, 19200 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights
# Resizing
# 896 x 896
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000052 seconds
#
#  301: 6.653071, 6.546471 avg loss, 0.000008 rate, 49.289834 seconds, 19264 images
# Loaded: 0.000053 seconds
#
#  302: 5.858905, 6.477714 avg loss, 0.000008 rate, 49.599569 seconds, 19328 images
# Loaded: 0.000057 seconds
#
#  303: 6.387282, 6.468671 avg loss, 0.000008 rate, 49.563531 seconds, 19392 images
# Loaded: 0.000044 seconds
#
#  304: 6.482869, 6.470091 avg loss, 0.000009 rate, 49.654646 seconds, 19456 images
# Loaded: 0.000062 seconds
#
#  305: 7.180839, 6.541166 avg loss, 0.000009 rate, 49.526484 seconds, 19520 images
# Loaded: 0.000062 seconds
#
#  306: 7.726862, 6.659736 avg loss, 0.000009 rate, 49.735332 seconds, 19584 images
# Loaded: 0.000050 seconds
#
#  307: 6.117129, 6.605475 avg loss, 0.000009 rate, 49.636161 seconds, 19648 images
# Loaded: 0.000049 seconds
#
#  308: 4.875764, 6.432504 avg loss, 0.000009 rate, 49.588564 seconds, 19712 images
# Loaded: 0.000054 seconds
#
#  309: 6.492498, 6.438503 avg loss, 0.000009 rate, 49.604654 seconds, 19776 images
# Loaded: 0.000056 seconds
#
#  310: 6.783665, 6.473020 avg loss, 0.000009 rate, 49.645616 seconds, 19840 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 1.475867 seconds
#
#  311: 5.222617, 6.347980 avg loss, 0.000009 rate, 43.353958 seconds, 19904 images
# Loaded: 0.000053 seconds
#
#  312: 6.776345, 6.390816 avg loss, 0.000009 rate, 43.892045 seconds, 19968 images
# Loaded: 0.000081 seconds
#
#  313: 6.027219, 6.354456 avg loss, 0.000010 rate, 43.809778 seconds, 20032 images
# Loaded: 0.000076 seconds
#
#  314: 6.928977, 6.411909 avg loss, 0.000010 rate, 43.883585 seconds, 20096 images
# Loaded: 0.000054 seconds
#
#  315: 7.516953, 6.522413 avg loss, 0.000010 rate, 43.907174 seconds, 20160 images
# Loaded: 0.000083 seconds
#
#  316: 6.526632, 6.522835 avg loss, 0.000010 rate, 43.730519 seconds, 20224 images
# Loaded: 0.000074 seconds
#
#  317: 4.578154, 6.328367 avg loss, 0.000010 rate, 43.685077 seconds, 20288 images
# Loaded: 0.000067 seconds
#
#  318: 6.514246, 6.346955 avg loss, 0.000010 rate, 43.713391 seconds, 20352 images
# Loaded: 0.000055 seconds
#
#  319: 8.002546, 6.512515 avg loss, 0.000010 rate, 43.906704 seconds, 20416 images
# Loaded: 0.000056 seconds
#
#  320: 5.646122, 6.425875 avg loss, 0.000010 rate, 43.793875 seconds, 20480 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 4.15 MB
#  CUDA allocate done!
# Loaded: 0.430539 seconds
#
#  321: 6.973035, 6.480591 avg loss, 0.000011 rate, 16.061584 seconds, 20544 images
# Loaded: 0.000041 seconds
#
#  322: 7.703596, 6.602892 avg loss, 0.000011 rate, 16.150599 seconds, 20608 images
# Loaded: 0.000055 seconds
#
#  323: 3.920922, 6.334695 avg loss, 0.000011 rate, 16.113187 seconds, 20672 images
# Loaded: 0.000057 seconds
#
#  324: 6.300096, 6.331235 avg loss, 0.000011 rate, 16.085028 seconds, 20736 images
# Loaded: 0.000058 seconds
#
#  325: 6.351304, 6.333242 avg loss, 0.000011 rate, 16.104067 seconds, 20800 images
# Loaded: 0.000045 seconds
#
#  326: 5.603666, 6.260284 avg loss, 0.000011 rate, 16.132955 seconds, 20864 images
# Loaded: 0.000046 seconds
#
#  327: 6.685277, 6.302784 avg loss, 0.000011 rate, 16.092823 seconds, 20928 images
# Loaded: 0.000057 seconds
#
#  328: 5.997155, 6.272221 avg loss, 0.000012 rate, 16.191341 seconds, 20992 images
# Loaded: 0.000057 seconds
#
#  329: 5.870162, 6.232015 avg loss, 0.000012 rate, 16.104602 seconds, 21056 images
# Loaded: 0.000051 seconds
#
#  330: 7.296275, 6.338441 avg loss, 0.000012 rate, 16.098732 seconds, 21120 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 5.97 MB
#  CUDA allocate done!
# Loaded: 0.000045 seconds
#
#  331: 6.443264, 6.348924 avg loss, 0.000012 rate, 22.145345 seconds, 21184 images
# Loaded: 0.000067 seconds
#
#  332: 5.104599, 6.224491 avg loss, 0.000012 rate, 22.341635 seconds, 21248 images
# Loaded: 0.000052 seconds
#
#  333: 6.276412, 6.229683 avg loss, 0.000012 rate, 22.406057 seconds, 21312 images
# Loaded: 0.000070 seconds
#
#  334: 6.346303, 6.241345 avg loss, 0.000012 rate, 22.410736 seconds, 21376 images
# Loaded: 0.000052 seconds
#
#  335: 5.852486, 6.202459 avg loss, 0.000013 rate, 22.339099 seconds, 21440 images
# Loaded: 0.000075 seconds
#
#  336: 5.579066, 6.140120 avg loss, 0.000013 rate, 22.342337 seconds, 21504 images
# Loaded: 0.000055 seconds
#
#  337: 6.209770, 6.147085 avg loss, 0.000013 rate, 22.381681 seconds, 21568 images
# Loaded: 0.000062 seconds
#
#  338: 5.408918, 6.073268 avg loss, 0.000013 rate, 22.344629 seconds, 21632 images
# Loaded: 0.000049 seconds
#
#  339: 6.655088, 6.131450 avg loss, 0.000013 rate, 22.360650 seconds, 21696 images
# Loaded: 0.000077 seconds
#
#  340: 6.002929, 6.118598 avg loss, 0.000013 rate, 22.353656 seconds, 21760 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 6.65 MB
#  CUDA allocate done!
# Loaded: 0.000049 seconds
#
#  341: 5.448622, 6.051600 avg loss, 0.000014 rate, 24.319421 seconds, 21824 images
# Loaded: 0.000060 seconds
#
# ...
# Loaded: 0.000065 seconds
#
#  1339: 1.314026, 1.462181 avg loss, 0.001000 rate, 41.075267 seconds, 85696 images
# Loaded: 0.000096 seconds
#
#  1340: 1.512905, 1.467254 avg loss, 0.001000 rate, 41.226472 seconds, 85760 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 4.72 MB
#  CUDA allocate done!
# Loaded: 0.231151 seconds
#
#  1341: 1.564206, 1.476949 avg loss, 0.001000 rate, 17.134260 seconds, 85824 images
# Loaded: 0.000053 seconds
#
#  1342: 1.647285, 1.493983 avg loss, 0.001000 rate, 17.312047 seconds, 85888 images
# Loaded: 0.000059 seconds
#
#  1343: 1.465975, 1.491182 avg loss, 0.001000 rate, 17.314199 seconds, 85952 images
# Loaded: 0.000058 seconds
#
#  1344: 1.630159, 1.505080 avg loss, 0.001000 rate, 17.366229 seconds, 86016 images
# Loaded: 0.000056 seconds
#
#  1345: 1.434307, 1.498002 avg loss, 0.001000 rate, 17.324850 seconds, 86080 images
# Loaded: 0.000049 seconds
#
#  1346: 1.671248, 1.515327 avg loss, 0.001000 rate, 17.292946 seconds, 86144 images
# Loaded: 0.000054 seconds
#
#  1347: 1.770326, 1.540827 avg loss, 0.001000 rate, 17.319006 seconds, 86208 images
# Loaded: 0.000084 seconds
#
#  1348: 1.264326, 1.513177 avg loss, 0.001000 rate, 17.278201 seconds, 86272 images
# Loaded: 0.000054 seconds
#
#  1349: 1.616903, 1.523549 avg loss, 0.001000 rate, 17.336114 seconds, 86336 images
# Loaded: 0.000072 seconds
#
#  1350: 1.241359, 1.495330 avg loss, 0.001000 rate, 17.282492 seconds, 86400 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000070 seconds
#
#  1351: 1.844287, 1.530226 avg loss, 0.001000 rate, 43.878743 seconds, 86464 images
# Loaded: 0.000041 seconds
#
#  1352: 1.388417, 1.516045 avg loss, 0.001000 rate, 43.967520 seconds, 86528 images
# Loaded: 0.000077 seconds
#
#  1353: 1.607927, 1.525233 avg loss, 0.001000 rate, 43.987434 seconds, 86592 images
# Loaded: 0.000058 seconds
#
#  1354: 1.839029, 1.556613 avg loss, 0.001000 rate, 44.096731 seconds, 86656 images
# Loaded: 0.000079 seconds
#
#  1355: 1.882686, 1.589220 avg loss, 0.001000 rate, 44.030557 seconds, 86720 images
# Loaded: 0.000059 seconds
#
#  1356: 1.522559, 1.582554 avg loss, 0.001000 rate, 44.034757 seconds, 86784 images
# Loaded: 0.000057 seconds
#
#  1357: 1.483994, 1.572698 avg loss, 0.001000 rate, 44.033291 seconds, 86848 images
# Loaded: 0.000117 seconds
#
#  1358: 1.705394, 1.585968 avg loss, 0.001000 rate, 44.051358 seconds, 86912 images
# Loaded: 0.000066 seconds
#
#  1359: 1.774192, 1.604790 avg loss, 0.001000 rate, 43.913039 seconds, 86976 images
# Loaded: 0.000057 seconds
#
#  1360: 1.789900, 1.623301 avg loss, 0.001000 rate, 44.102546 seconds, 87040 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 5.97 MB
#  CUDA allocate done!
# Loaded: 0.000057 seconds
#
#  1361: 1.421415, 1.603112 avg loss, 0.001000 rate, 22.314774 seconds, 87104 images
# Loaded: 0.000055 seconds
#
#  1362: 1.625460, 1.605347 avg loss, 0.001000 rate, 22.467544 seconds, 87168 images
# Loaded: 0.000064 seconds
#
#  1363: 1.470329, 1.591845 avg loss, 0.001000 rate, 22.477720 seconds, 87232 images
# Loaded: 0.000060 seconds
#
#  1364: 1.374923, 1.570153 avg loss, 0.001000 rate, 22.491573 seconds, 87296 images
# Loaded: 0.000062 seconds
#
#  1365: 1.578751, 1.571013 avg loss, 0.001000 rate, 22.543155 seconds, 87360 images
# Loaded: 0.000053 seconds
#
#  1366: 1.498035, 1.563715 avg loss, 0.001000 rate, 22.578817 seconds, 87424 images
# Loaded: 0.000050 seconds
#
#  1367: 1.410113, 1.548355 avg loss, 0.001000 rate, 22.521707 seconds, 87488 images
# Loaded: 0.000069 seconds
#
#  1368: 1.059925, 1.499512 avg loss, 0.001000 rate, 22.408774 seconds, 87552 images
# Loaded: 0.000073 seconds
#
#  1369: 1.331036, 1.482664 avg loss, 0.001000 rate, 22.458086 seconds, 87616 images
# Loaded: 0.000180 seconds
#
#  1370: 1.998402, 1.534238 avg loss, 0.001000 rate, 22.566054 seconds, 87680 images
# Resizing
# 768 x 768
#  try to allocate additional workspace_size = 10.62 MB
#  CUDA allocate done!
# Loaded: 0.000052 seconds
#
#  1371: 2.103146, 1.591129 avg loss, 0.001000 rate, 37.624559 seconds, 87744 images
# Loaded: 0.000087 seconds
#
#  1372: 1.481588, 1.580175 avg loss, 0.001000 rate, 37.825334 seconds, 87808 images
# Loaded: 0.000086 seconds
#
#  1373: 1.425218, 1.564679 avg loss, 0.001000 rate, 37.826674 seconds, 87872 images
# Loaded: 0.000097 seconds
#
#  1374: 1.145134, 1.522725 avg loss, 0.001000 rate, 37.808662 seconds, 87936 images
# Loaded: 0.000053 seconds
#
#  1375: 1.673010, 1.537753 avg loss, 0.001000 rate, 37.761224 seconds, 88000 images
# Loaded: 0.000056 seconds
#
#  1376: 1.587141, 1.542692 avg loss, 0.001000 rate, 37.814970 seconds, 88064 images
# Loaded: 0.000074 seconds
#
#  1377: 1.308534, 1.519276 avg loss, 0.001000 rate, 37.796845 seconds, 88128 images
# Loaded: 0.000050 seconds
#
#  1378: 1.751632, 1.542512 avg loss, 0.001000 rate, 37.861644 seconds, 88192 images
# Loaded: 0.000074 seconds
#
#  1379: 1.318091, 1.520070 avg loss, 0.001000 rate, 37.806956 seconds, 88256 images
# Loaded: 0.000054 seconds
#
#  1380: 1.359032, 1.503966 avg loss, 0.001000 rate, 37.750929 seconds, 88320 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 4.72 MB
#  CUDA allocate done!
# Loaded: 0.492364 seconds
#
#  1381: 1.535179, 1.507087 avg loss, 0.001000 rate, 17.188812 seconds, 88384 images
# Loaded: 0.000047 seconds
#
#  1382: 2.707339, 1.627112 avg loss, 0.001000 rate, 17.343938 seconds, 88448 images
# Loaded: 0.000045 seconds
#
#  1383: 1.600306, 1.624432 avg loss, 0.001000 rate, 17.289822 seconds, 88512 images
# Loaded: 0.000090 seconds
#
#  1384: 1.545328, 1.616521 avg loss, 0.001000 rate, 17.359184 seconds, 88576 images
# Loaded: 0.000062 seconds
#
#  1385: 1.585119, 1.613381 avg loss, 0.001000 rate, 17.364795 seconds, 88640 images
# Loaded: 0.000076 seconds
#
#  1386: 1.697759, 1.621819 avg loss, 0.001000 rate, 17.319927 seconds, 88704 images
# Loaded: 0.000059 seconds
#
#  1387: 1.756246, 1.635262 avg loss, 0.001000 rate, 17.299032 seconds, 88768 images
# Loaded: 0.000053 seconds
#
#  1388: 1.502744, 1.622010 avg loss, 0.001000 rate, 17.340625 seconds, 88832 images
# Loaded: 0.000057 seconds
#
#  1389: 1.818431, 1.641652 avg loss, 0.001000 rate, 17.350029 seconds, 88896 images
# Loaded: 0.000054 seconds
#
#  1390: 1.283648, 1.605852 avg loss, 0.001000 rate, 17.290066 seconds, 88960 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 4.15 MB
#  CUDA allocate done!
# Loaded: 0.878337 seconds
#
#  1391: 1.354328, 1.580699 avg loss, 0.001000 rate, 16.067578 seconds, 89024 images
# Loaded: 0.000069 seconds
#
#  1392: 1.347885, 1.557418 avg loss, 0.001000 rate, 16.177554 seconds, 89088 images
# Loaded: 0.000059 seconds
#
#  1393: 1.515171, 1.553193 avg loss, 0.001000 rate, 16.208787 seconds, 89152 images
# Loaded: 0.000052 seconds
#
#  1394: 1.568075, 1.554681 avg loss, 0.001000 rate, 16.133689 seconds, 89216 images
# Loaded: 0.000065 seconds
#
#  1395: 1.583569, 1.557570 avg loss, 0.001000 rate, 16.212541 seconds, 89280 images
# Loaded: 0.000055 seconds
#
#  1396: 1.267260, 1.528539 avg loss, 0.001000 rate, 16.159264 seconds, 89344 images
# Loaded: 0.000048 seconds
#
#  1397: 1.418222, 1.517507 avg loss, 0.001000 rate, 16.216327 seconds, 89408 images
# Loaded: 0.000074 seconds
#
#  1398: 1.487345, 1.514491 avg loss, 0.001000 rate, 16.188528 seconds, 89472 images
# Loaded: 0.000047 seconds
#
#  1399: 1.725360, 1.535578 avg loss, 0.001000 rate, 16.211536 seconds, 89536 images
# Loaded: 0.000066 seconds
#
#  1400: 1.447571, 1.526777 avg loss, 0.001000 rate, 16.093485 seconds, 89600 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights
# Resizing
# 672 x 672
#  try to allocate additional workspace_size = 8.13 MB
#  CUDA allocate done!
# Loaded: 0.000081 seconds
#
#  1401: 1.705802, 1.544680 avg loss, 0.001000 rate, 29.645969 seconds, 89664 images
# Loaded: 0.000070 seconds
#
#  1402: 1.132489, 1.503461 avg loss, 0.001000 rate, 29.848155 seconds, 89728 images
# Loaded: 0.000077 seconds
#
#  1403: 1.629866, 1.516101 avg loss, 0.001000 rate, 29.923797 seconds, 89792 images
# Loaded: 0.000040 seconds
#
#  1404: 1.466378, 1.511129 avg loss, 0.001000 rate, 29.896436 seconds, 89856 images
# Loaded: 0.000098 seconds
#
#  1405: 1.383530, 1.498369 avg loss, 0.001000 rate, 29.843311 seconds, 89920 images
# Loaded: 0.000063 seconds
#
#  1406: 1.751022, 1.523634 avg loss, 0.001000 rate, 29.898862 seconds, 89984 images
# Loaded: 0.000087 seconds
#
#  1407: 1.407652, 1.512036 avg loss, 0.001000 rate, 29.933920 seconds, 90048 images
# Loaded: 0.000063 seconds
#
#  1408: 1.680440, 1.528877 avg loss, 0.001000 rate, 29.846986 seconds, 90112 images
# Loaded: 0.000069 seconds
#
#  1409: 1.391270, 1.515116 avg loss, 0.001000 rate, 29.772442 seconds, 90176 images
# Loaded: 0.000070 seconds
#
#  1410: 1.259491, 1.489553 avg loss, 0.001000 rate, 29.824066 seconds, 90240 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 5.33 MB
#  CUDA allocate done!
# Loaded: 1.438566 seconds
#
#  1411: 1.244253, 1.465023 avg loss, 0.001000 rate, 20.044413 seconds, 90304 images
# Loaded: 0.000060 seconds
#
#  1412: 1.522038, 1.470725 avg loss, 0.001000 rate, 20.314656 seconds, 90368 images
# Loaded: 0.000070 seconds
#
#  1413: 1.219117, 1.445564 avg loss, 0.001000 rate, 20.225075 seconds, 90432 images
# Loaded: 0.000054 seconds
#
#  1414: 1.600133, 1.461021 avg loss, 0.001000 rate, 20.282780 seconds, 90496 images
# Loaded: 0.000060 seconds
#
#  1415: 1.678396, 1.482759 avg loss, 0.001000 rate, 20.305867 seconds, 90560 images
# Loaded: 0.000053 seconds
#
#  1416: 1.355827, 1.470065 avg loss, 0.001000 rate, 20.255789 seconds, 90624 images
# Loaded: 0.000059 seconds
#
#  1417: 1.426255, 1.465684 avg loss, 0.001000 rate, 20.264514 seconds, 90688 images
# Loaded: 0.000090 seconds
#
#  1418: 1.378780, 1.456994 avg loss, 0.001000 rate, 20.208265 seconds, 90752 images
# Loaded: 0.000045 seconds
#
#  1419: 1.612999, 1.472594 avg loss, 0.001000 rate, 20.182750 seconds, 90816 images
# Loaded: 0.000053 seconds
#
#  1420: 1.288810, 1.454216 avg loss, 0.001000 rate, 20.215079 seconds, 90880 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 4.15 MB
#  CUDA allocate done!
# Loaded: 0.836454 seconds
#
#  1421: 1.413058, 1.450100 avg loss, 0.001000 rate, 16.055202 seconds, 90944 images
# Loaded: 0.000046 seconds
#
#  1422: 1.942748, 1.499365 avg loss, 0.001000 rate, 16.228356 seconds, 91008 images
# Loaded: 0.000078 seconds
#
#  1423: 1.402515, 1.489680 avg loss, 0.001000 rate, 16.219878 seconds, 91072 images
# Loaded: 0.000057 seconds
#
#  1424: 1.618231, 1.502535 avg loss, 0.001000 rate, 16.122513 seconds, 91136 images
# Loaded: 0.000060 seconds
#
#  1425: 1.539230, 1.506205 avg loss, 0.001000 rate, 16.213768 seconds, 91200 images
# Loaded: 0.000085 seconds
#
#  1426: 1.310552, 1.486639 avg loss, 0.001000 rate, 16.138355 seconds, 91264 images
# Loaded: 0.000073 seconds
#
#  1427: 1.759909, 1.513966 avg loss, 0.001000 rate, 16.187045 seconds, 91328 images
# Loaded: 0.000065 seconds
#
#  1428: 1.564019, 1.518972 avg loss, 0.001000 rate, 16.216858 seconds, 91392 images
# Loaded: 0.000060 seconds
#
#  1429: 1.657658, 1.532840 avg loss, 0.001000 rate, 16.229163 seconds, 91456 images
# Loaded: 0.000057 seconds
#
#  1430: 1.300493, 1.509606 avg loss, 0.001000 rate, 16.135014 seconds, 91520 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 5.97 MB
#  CUDA allocate done!
# Loaded: 0.068455 seconds
#
#  1431: 1.591647, 1.517810 avg loss, 0.001000 rate, 22.274642 seconds, 91584 images
# Loaded: 0.000051 seconds
#
#  1432: 1.639915, 1.530020 avg loss, 0.001000 rate, 22.535424 seconds, 91648 images
# Loaded: 0.000080 seconds
#
#  1433: 1.215225, 1.498541 avg loss, 0.001000 rate, 22.482922 seconds, 91712 images
# Loaded: 0.000073 seconds
#
#  1434: 1.057318, 1.454419 avg loss, 0.001000 rate, 22.517213 seconds, 91776 images
# Loaded: 0.000059 seconds
#
#  1435: 1.277414, 1.436718 avg loss, 0.001000 rate, 22.443701 seconds, 91840 images
# Loaded: 0.000040 seconds
#
#  1436: 1.115234, 1.404570 avg loss, 0.001000 rate, 22.429892 seconds, 91904 images
# Loaded: 0.000038 seconds
#
#  1437: 1.391502, 1.403263 avg loss, 0.001000 rate, 22.551728 seconds, 91968 images
# Loaded: 0.000067 seconds
#
#  1438: 1.203910, 1.383328 avg loss, 0.001000 rate, 22.531563 seconds, 92032 images
# Loaded: 0.000068 seconds
#
#  1439: 1.457935, 1.390788 avg loss, 0.001000 rate, 22.578330 seconds, 92096 images
# Loaded: 0.000071 seconds
#
#  1440: 1.288163, 1.380526 avg loss, 0.001000 rate, 22.493144 seconds, 92160 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000054 seconds
#
#  1441: 1.752388, 1.417712 avg loss, 0.001000 rate, 43.838342 seconds, 92224 images
# Loaded: 0.000054 seconds
#
#  1442: 1.452678, 1.421209 avg loss, 0.001000 rate, 44.106852 seconds, 92288 images
# Loaded: 0.000084 seconds
#
#  1443: 1.535667, 1.432655 avg loss, 0.001000 rate, 43.974607 seconds, 92352 images
# Loaded: 0.000052 seconds
#
#  1444: 2.278332, 1.517222 avg loss, 0.001000 rate, 44.294082 seconds, 92416 images
# Loaded: 0.000083 seconds
#
#  1445: 1.615313, 1.527032 avg loss, 0.001000 rate, 44.046343 seconds, 92480 images
# Loaded: 0.000077 seconds
#
#  1446: 1.704562, 1.544785 avg loss, 0.001000 rate, 44.044798 seconds, 92544 images
# Loaded: 0.000072 seconds
#
#  1447: 1.785719, 1.568878 avg loss, 0.001000 rate, 44.157142 seconds, 92608 images
# Loaded: 0.000055 seconds
#
#  1448: 1.184096, 1.530400 avg loss, 0.001000 rate, 43.974617 seconds, 92672 images
# Loaded: 0.000054 seconds
#
#  1449: 1.616375, 1.538997 avg loss, 0.001000 rate, 44.134283 seconds, 92736 images
# Loaded: 0.000068 seconds
#
#  1450: 1.732804, 1.558378 avg loss, 0.001000 rate, 44.088254 seconds, 92800 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 9.75 MB
#  CUDA allocate done!
# Loaded: 1.598131 seconds
#
#  1451: 1.142360, 1.516776 avg loss, 0.001000 rate, 35.443492 seconds, 92864 images
# Loaded: 0.000047 seconds
#
#  1452: 1.610639, 1.526163 avg loss, 0.001000 rate, 35.839189 seconds, 92928 images
# Loaded: 0.000063 seconds
#
#  1453: 1.368519, 1.510398 avg loss, 0.001000 rate, 35.784194 seconds, 92992 images
# Loaded: 0.000059 seconds
#
#  1454: 1.821082, 1.541467 avg loss, 0.001000 rate, 35.789494 seconds, 93056 images
# Loaded: 0.000073 seconds
#
#  1455: 1.255309, 1.512851 avg loss, 0.001000 rate, 35.744470 seconds, 93120 images
# Loaded: 0.000064 seconds
#
#  1456: 1.164716, 1.478037 avg loss, 0.001000 rate, 35.819480 seconds, 93184 images
# Loaded: 0.000079 seconds
#
#  1457: 1.304407, 1.460674 avg loss, 0.001000 rate, 35.692225 seconds, 93248 images
# Loaded: 0.000058 seconds
#
#  1458: 1.457258, 1.460333 avg loss, 0.001000 rate, 35.899233 seconds, 93312 images
# Loaded: 0.000050 seconds
#
#  1459: 1.754099, 1.489709 avg loss, 0.001000 rate, 35.800525 seconds, 93376 images
# Loaded: 0.000057 seconds
#
#  1460: 1.645243, 1.505263 avg loss, 0.001000 rate, 35.785150 seconds, 93440 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 9.75 MB
#  CUDA allocate done!
# Loaded: 1.418829 seconds
#
#  1461: 1.629994, 1.517736 avg loss, 0.001000 rate, 35.557691 seconds, 93504 images
# Loaded: 0.000077 seconds
#
#  1462: 1.154543, 1.481416 avg loss, 0.001000 rate, 35.787643 seconds, 93568 images
# Loaded: 0.000081 seconds
#
#  1463: 1.426789, 1.475954 avg loss, 0.001000 rate, 35.784865 seconds, 93632 images
# Loaded: 0.000060 seconds
#
#  1464: 1.531368, 1.481495 avg loss, 0.001000 rate, 35.789140 seconds, 93696 images
# Loaded: 0.000072 seconds
#
#  1465: 1.580439, 1.491390 avg loss, 0.001000 rate, 35.870531 seconds, 93760 images
# Loaded: 0.000053 seconds
#
#  1466: 1.184315, 1.460682 avg loss, 0.001000 rate, 35.743741 seconds, 93824 images
# Loaded: 0.000084 seconds
#
#  1467: 1.499596, 1.464574 avg loss, 0.001000 rate, 35.683599 seconds, 93888 images
# Loaded: 0.000075 seconds
#
#  1468: 1.644047, 1.482521 avg loss, 0.001000 rate, 35.786524 seconds, 93952 images
# Loaded: 0.000066 seconds
#
#  1469: 1.435720, 1.477841 avg loss, 0.001000 rate, 35.805411 seconds, 94016 images
# Loaded: 0.000078 seconds
#
#  1470: 1.361354, 1.466192 avg loss, 0.001000 rate, 35.756211 seconds, 94080 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 4.72 MB
#  CUDA allocate done!
# Loaded: 0.033620 seconds
#
#  1471: 1.308512, 1.450424 avg loss, 0.001000 rate, 17.139883 seconds, 94144 images
# Loaded: 0.000048 seconds
# ^C

# %% [markdown]
# ## PERFORMANCE TIPS & TRICKS
#
# * **Speed up load times of the runtime:** When everything is checked that works, you can remove cells or comment unnecessary lines of code to make your loading time lower on every run.
#
# * **How to keep your notebook alive for more time?:** Keep you browser with your notebook open. If you close your browser, your notebook will reach the iddle time and will be removed from Colab cloud Service. (90 minutes)
#
# * **Re-run your training after reaching the limitation time for Colab runtimes (12 hours):**
#   * Open a new notebook or reconnect the current one.
#   * Comment the cell above and uncomment the cell below.
#   * In your local computer, copy the file **backup/yolov3_last.weights** to your local computer **weights/** folder.
#   * Execute Run all in the **> menu > Runtime > Run All**
#   * _The copy step is not absolutely necessary, but I like to keep a copy of the last training session and not overwrite this file on next trainings._

# %%
# Start training at the point where the last runtime finished
# !./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/cfg/yolov3-voc.cfg" "/content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights" -dont_show
# Out:
# yolov3-voc
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32 0.639 BF
#    1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64 3.407 BF
#    2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32 0.379 BF
#    3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128 3.407 BF
#    6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#    7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#   10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   152 x 152 x 128   ->    76 x  76 x 256 3.407 BF
#   13 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   14 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   17 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   20 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   23 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   26 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   29 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   32 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   35 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    76 x  76 x 256   ->    38 x  38 x 512 3.407 BF
#   38 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   39 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   42 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   45 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   48 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   51 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   54 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   57 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   60 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    38 x  38 x 512   ->    19 x  19 x1024 3.407 BF
#   63 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   64 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   67 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   70 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   73 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   76 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   77 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   78 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   79 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   80 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   81 conv     18  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x  18 0.013 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    19 x  19 x 512   ->    19 x  19 x 256 0.095 BF
#   85 upsample            2x    19 x  19 x 256   ->    38 x  38 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    38 x  38 x 768   ->    38 x  38 x 256 0.568 BF
#   88 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   89 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   90 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   91 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   92 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   93 conv     18  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x  18 0.027 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    38 x  38 x 256   ->    38 x  38 x 128 0.095 BF
#   97 upsample            2x    38 x  38 x 128   ->    76 x  76 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    76 x  76 x 384   ->    76 x  76 x 128 0.568 BF
#  100 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  101 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  102 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  103 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  104 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  105 conv     18  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x  18 0.053 BF
#  106 yolo
# Total BFLOPS 139.465
#  Allocate additional workspace_size = 55.45 MB
# Loading weights from /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights...
#  seen 64
# Done!
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
# Resizing
# 896 x 896
#  try to allocate additional workspace_size = 120.43 MB
#  CUDA allocate done!
# Loaded: 12.191962 seconds
#
#  1401: 1.507481, 1.507481 avg loss, 0.001000 rate, 21.585190 seconds, 89664 images
# Loaded: 0.000036 seconds
#
#  1402: 1.553508, 1.512084 avg loss, 0.001000 rate, 22.503447 seconds, 89728 images
# Loaded: 0.000046 seconds
#
#  1403: 1.430448, 1.503920 avg loss, 0.001000 rate, 22.559091 seconds, 89792 images
# Loaded: 0.000039 seconds
#
#  1404: 1.730247, 1.526553 avg loss, 0.001000 rate, 22.209701 seconds, 89856 images
# Loaded: 0.000034 seconds
#
#  1405: 1.477988, 1.521697 avg loss, 0.001000 rate, 22.111592 seconds, 89920 images
# Loaded: 0.000065 seconds
#
#  1406: 1.902672, 1.559794 avg loss, 0.001000 rate, 22.327595 seconds, 89984 images
# Loaded: 0.000067 seconds
#
#  1407: 1.590908, 1.562906 avg loss, 0.001000 rate, 22.436628 seconds, 90048 images
# Loaded: 0.000041 seconds
#
#  1408: 1.653022, 1.571917 avg loss, 0.001000 rate, 22.262714 seconds, 90112 images
# Loaded: 0.000039 seconds
#
#  1409: 1.838303, 1.598556 avg loss, 0.001000 rate, 22.265864 seconds, 90176 images
# Loaded: 0.000038 seconds
#
#  1410: 1.545744, 1.593274 avg loss, 0.001000 rate, 22.301310 seconds, 90240 images
# Resizing
# 640 x 640
#  try to allocate additional workspace_size = 61.44 MB
#  CUDA allocate done!
# Loaded: 11.020448 seconds
#
#  1411: 1.244583, 1.558405 avg loss, 0.001000 rate, 11.757419 seconds, 90304 images
# Loaded: 0.820237 seconds
#
#  1412: 1.193572, 1.521922 avg loss, 0.001000 rate, 12.018288 seconds, 90368 images
# Loaded: 4.483452 seconds
#
#  1413: 1.441723, 1.513902 avg loss, 0.001000 rate, 12.100862 seconds, 90432 images
# Loaded: 0.000037 seconds
#
#  1414: 1.323381, 1.494850 avg loss, 0.001000 rate, 12.102016 seconds, 90496 images
# Loaded: 0.341523 seconds
#
#  1415: 1.157690, 1.461134 avg loss, 0.001000 rate, 11.861180 seconds, 90560 images
# Loaded: 0.000040 seconds
#
#  1416: 1.186816, 1.433702 avg loss, 0.001000 rate, 11.872535 seconds, 90624 images
# Loaded: 0.000035 seconds
#
#  1417: 1.412001, 1.431532 avg loss, 0.001000 rate, 11.886526 seconds, 90688 images
# Loaded: 0.000031 seconds
#
#  1418: 1.390007, 1.427380 avg loss, 0.001000 rate, 11.893371 seconds, 90752 images
# Loaded: 0.000060 seconds
#
#  1419: 1.633077, 1.447949 avg loss, 0.001000 rate, 11.942201 seconds, 90816 images
# Loaded: 0.000039 seconds
#
#  1420: 1.163757, 1.419530 avg loss, 0.001000 rate, 11.933961 seconds, 90880 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 8.741232 seconds
#
#  1421: 1.650910, 1.442668 avg loss, 0.001000 rate, 7.667166 seconds, 90944 images
# Loaded: 3.067692 seconds
#
#  1422: 1.005535, 1.398955 avg loss, 0.001000 rate, 7.695927 seconds, 91008 images
# Loaded: 2.809585 seconds
#
#  1423: 1.744507, 1.433510 avg loss, 0.001000 rate, 7.803314 seconds, 91072 images
# Loaded: 1.475134 seconds
#
#  1424: 1.461515, 1.436311 avg loss, 0.001000 rate, 7.688413 seconds, 91136 images
# Loaded: 2.126147 seconds
#
#  1425: 1.816047, 1.474284 avg loss, 0.001000 rate, 7.793056 seconds, 91200 images
# Loaded: 0.954799 seconds
#
#  1426: 1.262984, 1.453154 avg loss, 0.001000 rate, 7.653037 seconds, 91264 images
# Loaded: 3.709477 seconds
#
#  1427: 1.499171, 1.457756 avg loss, 0.001000 rate, 7.676726 seconds, 91328 images
# Loaded: 2.423788 seconds
#
#  1428: 1.403302, 1.452310 avg loss, 0.001000 rate, 7.671176 seconds, 91392 images
# Loaded: 3.718429 seconds
#
#  1429: 1.693210, 1.476400 avg loss, 0.001000 rate, 7.720341 seconds, 91456 images
# Loaded: 2.942652 seconds
#
#  1430: 1.378748, 1.466635 avg loss, 0.001000 rate, 7.718913 seconds, 91520 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 5.350532 seconds
#
#  1431: 1.712685, 1.491240 avg loss, 0.001000 rate, 19.960129 seconds, 91584 images
# Loaded: 0.000056 seconds
#
#  1432: 1.469596, 1.489076 avg loss, 0.001000 rate, 20.172614 seconds, 91648 images
# Loaded: 0.000042 seconds
#
#  1433: 1.603343, 1.500502 avg loss, 0.001000 rate, 19.701042 seconds, 91712 images
# Loaded: 0.000051 seconds
#
#  1434: 1.407864, 1.491239 avg loss, 0.001000 rate, 19.540586 seconds, 91776 images
# Loaded: 0.000066 seconds
#
#  1435: 1.407258, 1.482841 avg loss, 0.001000 rate, 19.749723 seconds, 91840 images
# Loaded: 0.000052 seconds
#
#  1436: 1.649360, 1.499493 avg loss, 0.001000 rate, 19.984453 seconds, 91904 images
# Loaded: 0.000040 seconds
#
#  1437: 1.290280, 1.478571 avg loss, 0.001000 rate, 19.901474 seconds, 91968 images
# Loaded: 0.000061 seconds
#
#  1438: 1.188286, 1.449543 avg loss, 0.001000 rate, 19.738823 seconds, 92032 images
# Loaded: 0.000043 seconds
#
#  1439: 1.480674, 1.452656 avg loss, 0.001000 rate, 19.746355 seconds, 92096 images
# Loaded: 0.000045 seconds
#
#  1440: 1.132835, 1.420674 avg loss, 0.001000 rate, 19.706493 seconds, 92160 images
# Resizing
# 640 x 640
#  try to allocate additional workspace_size = 61.44 MB
#  CUDA allocate done!
# Loaded: 7.269640 seconds
#
#  1441: 1.648118, 1.443418 avg loss, 0.001000 rate, 11.813855 seconds, 92224 images
# Loaded: 0.000034 seconds
#
#  1442: 1.314260, 1.430502 avg loss, 0.001000 rate, 12.060041 seconds, 92288 images
# Loaded: 0.000037 seconds
#
#  1443: 1.344583, 1.421910 avg loss, 0.001000 rate, 12.129154 seconds, 92352 images
# Loaded: 0.000031 seconds
#
#  1444: 1.432661, 1.422986 avg loss, 0.001000 rate, 12.080588 seconds, 92416 images
# Loaded: 0.000031 seconds
#
#  1445: 1.509230, 1.431610 avg loss, 0.001000 rate, 11.986847 seconds, 92480 images
# Loaded: 0.000042 seconds
#
#  1446: 1.371990, 1.425648 avg loss, 0.001000 rate, 11.924671 seconds, 92544 images
# Loaded: 0.000040 seconds
#
#  1447: 1.577172, 1.440800 avg loss, 0.001000 rate, 11.876527 seconds, 92608 images
# Loaded: 0.000034 seconds
#
#  1448: 1.366001, 1.433321 avg loss, 0.001000 rate, 11.930923 seconds, 92672 images
# Loaded: 0.000039 seconds
#
#  1449: 1.148775, 1.404866 avg loss, 0.001000 rate, 11.958440 seconds, 92736 images
# Loaded: 0.000037 seconds
#
#  1450: 1.134105, 1.377790 avg loss, 0.001000 rate, 11.963874 seconds, 92800 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 96.00 MB
#  CUDA allocate done!
# Loaded: 5.656461 seconds
#
#  1451: 1.586648, 1.398676 avg loss, 0.001000 rate, 18.436732 seconds, 92864 images
# Loaded: 0.000047 seconds
#
#  1452: 1.714703, 1.430278 avg loss, 0.001000 rate, 18.735596 seconds, 92928 images
# Loaded: 0.000040 seconds
#
#  1453: 1.673916, 1.454642 avg loss, 0.001000 rate, 18.642149 seconds, 92992 images
# Loaded: 0.000045 seconds
#
#  1454: 1.279891, 1.437167 avg loss, 0.001000 rate, 18.396485 seconds, 93056 images
# Loaded: 0.000063 seconds
#
#  1455: 1.458490, 1.439299 avg loss, 0.001000 rate, 18.396819 seconds, 93120 images
# Loaded: 0.000040 seconds
#
#  1456: 1.425837, 1.437953 avg loss, 0.001000 rate, 18.569458 seconds, 93184 images
# Loaded: 0.000048 seconds
#
#  1457: 1.270651, 1.421223 avg loss, 0.001000 rate, 18.651481 seconds, 93248 images
# Loaded: 0.000065 seconds
#
#  1458: 1.323360, 1.411437 avg loss, 0.001000 rate, 18.598208 seconds, 93312 images
# Loaded: 0.000041 seconds
#
#  1459: 1.611256, 1.431419 avg loss, 0.001000 rate, 18.573679 seconds, 93376 images
# Loaded: 0.000048 seconds
#
#  1460: 1.470786, 1.435355 avg loss, 0.001000 rate, 18.507801 seconds, 93440 images
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 111.98 MB
#  CUDA allocate done!
# Loaded: 2.243461 seconds
#
#  1461: 1.632532, 1.455073 avg loss, 0.001000 rate, 21.172380 seconds, 93504 images
# Loaded: 0.000037 seconds
#
#  1462: 1.263556, 1.435921 avg loss, 0.001000 rate, 21.454395 seconds, 93568 images
# Loaded: 0.000037 seconds
#
#  1463: 1.120745, 1.404404 avg loss, 0.001000 rate, 21.185848 seconds, 93632 images
# Loaded: 0.000055 seconds
#
#  1464: 1.399574, 1.403921 avg loss, 0.001000 rate, 21.144291 seconds, 93696 images
# Loaded: 0.000052 seconds
#
#  1465: 1.344165, 1.397945 avg loss, 0.001000 rate, 21.128584 seconds, 93760 images
# Loaded: 0.000064 seconds
#
#  1466: 1.305234, 1.388674 avg loss, 0.001000 rate, 21.200491 seconds, 93824 images
# Loaded: 0.000065 seconds
#
#  1467: 1.321756, 1.381982 avg loss, 0.001000 rate, 21.228857 seconds, 93888 images
# Loaded: 0.000041 seconds
#
#  1468: 1.738847, 1.417669 avg loss, 0.001000 rate, 21.358114 seconds, 93952 images
# Loaded: 0.000047 seconds
#
#  1469: 1.448367, 1.420738 avg loss, 0.001000 rate, 21.307291 seconds, 94016 images
# Loaded: 0.000048 seconds
#
#  1470: 1.421587, 1.420823 avg loss, 0.001000 rate, 21.318109 seconds, 94080 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 3.521377 seconds
#
#  1471: 1.587712, 1.437512 avg loss, 0.001000 rate, 7.682208 seconds, 94144 images
# Loaded: 0.000052 seconds
#
#  1472: 1.734426, 1.467203 avg loss, 0.001000 rate, 7.740397 seconds, 94208 images
# Loaded: 0.000038 seconds
#
#  1473: 1.211546, 1.441638 avg loss, 0.001000 rate, 7.690155 seconds, 94272 images
# Loaded: 0.000038 seconds
#
#  1474: 1.348823, 1.432356 avg loss, 0.001000 rate, 7.724647 seconds, 94336 images
# Loaded: 0.000039 seconds
#
#  1475: 1.312248, 1.420345 avg loss, 0.001000 rate, 7.721795 seconds, 94400 images
# Loaded: 0.000032 seconds
#
#  1476: 1.814988, 1.459810 avg loss, 0.001000 rate, 7.755722 seconds, 94464 images
# Loaded: 0.000048 seconds
#
#  1477: 1.267947, 1.440624 avg loss, 0.001000 rate, 7.704715 seconds, 94528 images
# Loaded: 0.000032 seconds
#
#  1478: 1.536057, 1.450167 avg loss, 0.001000 rate, 7.726231 seconds, 94592 images
# Loaded: 0.000047 seconds
#
#  1479: 1.485188, 1.453669 avg loss, 0.001000 rate, 7.708013 seconds, 94656 images
# Loaded: 0.000034 seconds
#
#  1480: 1.610243, 1.469326 avg loss, 0.001000 rate, 7.688897 seconds, 94720 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 81.26 MB
#  CUDA allocate done!
# Loaded: 2.748009 seconds
#
#  1481: 1.351339, 1.457528 avg loss, 0.001000 rate, 15.512338 seconds, 94784 images
# Loaded: 0.000044 seconds
#
#  1482: 1.362187, 1.447994 avg loss, 0.001000 rate, 15.646398 seconds, 94848 images
# Loaded: 0.000039 seconds
#
#  1483: 1.335655, 1.436760 avg loss, 0.001000 rate, 15.695761 seconds, 94912 images
# Loaded: 0.000055 seconds
#
#  1484: 1.282220, 1.421306 avg loss, 0.001000 rate, 15.682045 seconds, 94976 images
# Loaded: 0.000085 seconds
#
#  1485: 1.593033, 1.438478 avg loss, 0.001000 rate, 15.629820 seconds, 95040 images
# Loaded: 0.000042 seconds
#
#  1486: 1.484869, 1.443118 avg loss, 0.001000 rate, 15.634515 seconds, 95104 images
# Loaded: 0.000035 seconds
#
#  1487: 1.553415, 1.454147 avg loss, 0.001000 rate, 15.581727 seconds, 95168 images
# Loaded: 0.000037 seconds
#
#  1488: 1.310571, 1.439790 avg loss, 0.001000 rate, 15.585504 seconds, 95232 images
# Loaded: 0.000038 seconds
#
#  1489: 1.253885, 1.421199 avg loss, 0.001000 rate, 15.636221 seconds, 95296 images
# Loaded: 0.000036 seconds
#
#  1490: 1.073811, 1.386460 avg loss, 0.001000 rate, 15.592491 seconds, 95360 images
# Resizing
# 640 x 640
#  try to allocate additional workspace_size = 61.44 MB
#  CUDA allocate done!
# Loaded: 3.363522 seconds
#
#  1491: 1.490022, 1.396816 avg loss, 0.001000 rate, 11.878602 seconds, 95424 images
# Loaded: 0.000038 seconds
#
#  1492: 1.707393, 1.427874 avg loss, 0.001000 rate, 12.075987 seconds, 95488 images
# Loaded: 0.000041 seconds
#
#  1493: 1.314437, 1.416530 avg loss, 0.001000 rate, 12.003749 seconds, 95552 images
# Loaded: 0.000037 seconds
#
#  1494: 1.231372, 1.398015 avg loss, 0.001000 rate, 12.026336 seconds, 95616 images
# Loaded: 0.000037 seconds
#
#  1495: 1.217579, 1.379971 avg loss, 0.001000 rate, 11.979731 seconds, 95680 images
# Loaded: 0.000047 seconds
#
#  1496: 1.466525, 1.388626 avg loss, 0.001000 rate, 11.942158 seconds, 95744 images
# Loaded: 0.000040 seconds
#
#  1497: 1.571704, 1.406934 avg loss, 0.001000 rate, 11.956522 seconds, 95808 images
# Loaded: 0.000034 seconds
#
#  1498: 1.137613, 1.380002 avg loss, 0.001000 rate, 11.932322 seconds, 95872 images
# Loaded: 0.000040 seconds
#
#  1499: 1.315261, 1.373528 avg loss, 0.001000 rate, 11.910234 seconds, 95936 images
# Loaded: 0.000039 seconds
#
#  1500: 1.448698, 1.381045 avg loss, 0.001000 rate, 11.891064 seconds, 96000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 3.832516 seconds
#
#  1501: 1.278075, 1.370748 avg loss, 0.001000 rate, 10.257695 seconds, 96064 images
# Loaded: 0.000040 seconds
#
#  1502: 1.350033, 1.368676 avg loss, 0.001000 rate, 10.335603 seconds, 96128 images
# Loaded: 0.000062 seconds
#
#  1503: 1.149784, 1.346787 avg loss, 0.001000 rate, 10.367362 seconds, 96192 images
# Loaded: 0.000038 seconds
#
#  1504: 1.439803, 1.356089 avg loss, 0.001000 rate, 10.385078 seconds, 96256 images
# Loaded: 0.000040 seconds
#
#  1505: 1.428570, 1.363337 avg loss, 0.001000 rate, 10.376926 seconds, 96320 images
# Loaded: 0.000030 seconds
#
#  1506: 1.579659, 1.384969 avg loss, 0.001000 rate, 10.398472 seconds, 96384 images
# Loaded: 0.000036 seconds
#
#  1507: 1.229544, 1.369426 avg loss, 0.001000 rate, 10.327058 seconds, 96448 images
# Loaded: 0.000035 seconds
#
#  1508: 1.277758, 1.360260 avg loss, 0.001000 rate, 10.311814 seconds, 96512 images
# Loaded: 0.000044 seconds
#
#  1509: 1.329178, 1.357152 avg loss, 0.001000 rate, 10.305310 seconds, 96576 images
# Loaded: 0.000038 seconds
#
#  1510: 1.212943, 1.342731 avg loss, 0.001000 rate, 10.310948 seconds, 96640 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 55.45 MB
#  CUDA allocate done!
# Loaded: 1.974540 seconds
#
#  1511: 1.430447, 1.351502 avg loss, 0.001000 rate, 11.074052 seconds, 96704 images
# Loaded: 0.000046 seconds
#
#  1512: 1.870940, 1.403446 avg loss, 0.001000 rate, 11.185661 seconds, 96768 images
# Loaded: 0.000036 seconds
#
#  1513: 1.387663, 1.401868 avg loss, 0.001000 rate, 11.211557 seconds, 96832 images
# Loaded: 0.000046 seconds
#
#  1514: 1.180264, 1.379707 avg loss, 0.001000 rate, 11.212004 seconds, 96896 images
# Loaded: 0.000036 seconds
#
#  1515: 1.481888, 1.389925 avg loss, 0.001000 rate, 11.275891 seconds, 96960 images
# Loaded: 0.000034 seconds
#
#  1516: 1.434672, 1.394400 avg loss, 0.001000 rate, 11.216705 seconds, 97024 images
# Loaded: 0.000047 seconds
#
#  1517: 1.087774, 1.363737 avg loss, 0.001000 rate, 11.184807 seconds, 97088 images
# Loaded: 0.000035 seconds
#
#  1518: 0.997502, 1.327114 avg loss, 0.001000 rate, 11.154561 seconds, 97152 images
# Loaded: 0.000036 seconds
#
#  1519: 1.603933, 1.354796 avg loss, 0.001000 rate, 11.188417 seconds, 97216 images
# Loaded: 0.000034 seconds
#
#  1520: 1.305831, 1.349900 avg loss, 0.001000 rate, 11.162617 seconds, 97280 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 96.00 MB
#  CUDA allocate done!
# Loaded: 0.000038 seconds
#
#  1521: 1.395471, 1.354457 avg loss, 0.001000 rate, 18.396665 seconds, 97344 images
# Loaded: 0.000066 seconds
#
#  1522: 1.541037, 1.373115 avg loss, 0.001000 rate, 18.622133 seconds, 97408 images
# Loaded: 0.000065 seconds
#
#  1523: 1.330429, 1.368846 avg loss, 0.001000 rate, 18.586139 seconds, 97472 images
# Loaded: 0.000042 seconds
#
#  1524: 1.489124, 1.380874 avg loss, 0.001000 rate, 18.621084 seconds, 97536 images
# Loaded: 0.000049 seconds
#
#  1525: 1.340837, 1.376870 avg loss, 0.001000 rate, 18.545605 seconds, 97600 images
# Loaded: 0.000038 seconds
#
#  1526: 1.441074, 1.383291 avg loss, 0.001000 rate, 18.560679 seconds, 97664 images
# Loaded: 0.000054 seconds
#
#  1527: 1.340632, 1.379025 avg loss, 0.001000 rate, 18.506596 seconds, 97728 images
# Loaded: 0.000053 seconds
#
#  1528: 1.580859, 1.399208 avg loss, 0.001000 rate, 18.485553 seconds, 97792 images
# Loaded: 0.000043 seconds
#
#  1529: 1.432928, 1.402580 avg loss, 0.001000 rate, 18.553619 seconds, 97856 images
# Loaded: 0.000050 seconds
#
#  1530: 1.337626, 1.396085 avg loss, 0.001000 rate, 18.531160 seconds, 97920 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 96.00 MB
#  CUDA allocate done!
# Loaded: 2.944061 seconds
#
#  1531: 1.585079, 1.414984 avg loss, 0.001000 rate, 18.484094 seconds, 97984 images
# Loaded: 0.000042 seconds
#
#  1532: 1.580729, 1.431559 avg loss, 0.001000 rate, 18.716423 seconds, 98048 images
# Loaded: 0.000056 seconds
#
#  1533: 1.229060, 1.411309 avg loss, 0.001000 rate, 18.576310 seconds, 98112 images
# Loaded: 0.000041 seconds
#
#  1534: 1.037207, 1.373899 avg loss, 0.001000 rate, 18.530037 seconds, 98176 images
# Loaded: 0.000072 seconds
#
#  1535: 1.331056, 1.369614 avg loss, 0.001000 rate, 18.565749 seconds, 98240 images
# Loaded: 0.000069 seconds
#
#  1536: 1.302134, 1.362866 avg loss, 0.001000 rate, 18.535036 seconds, 98304 images
# Loaded: 0.000047 seconds
#
#  1537: 1.043451, 1.330925 avg loss, 0.001000 rate, 18.501242 seconds, 98368 images
# Loaded: 0.000048 seconds
#
#  1538: 1.317519, 1.329584 avg loss, 0.001000 rate, 18.504288 seconds, 98432 images
# Loaded: 0.000042 seconds
#
#  1539: 1.180104, 1.314636 avg loss, 0.001000 rate, 18.566806 seconds, 98496 images
# Loaded: 0.000055 seconds
#
#  1540: 1.462905, 1.329463 avg loss, 0.001000 rate, 18.610260 seconds, 98560 images
# Resizing
# 704 x 704
#  try to allocate additional workspace_size = 74.35 MB
#  CUDA allocate done!
# Loaded: 1.159871 seconds
#
#  1541: 1.154769, 1.311994 avg loss, 0.001000 rate, 14.053726 seconds, 98624 images
# Loaded: 0.000051 seconds
#
#  1542: 1.551247, 1.335919 avg loss, 0.001000 rate, 14.295665 seconds, 98688 images
# Loaded: 0.000072 seconds
#
#  1543: 1.152176, 1.317545 avg loss, 0.001000 rate, 14.196962 seconds, 98752 images
# Loaded: 0.000032 seconds
#
#  1544: 1.603848, 1.346175 avg loss, 0.001000 rate, 14.298265 seconds, 98816 images
# Loaded: 0.000051 seconds
#
#  1545: 1.382413, 1.349799 avg loss, 0.001000 rate, 14.200717 seconds, 98880 images
# Loaded: 0.000030 seconds
#
#  1546: 1.476352, 1.362454 avg loss, 0.001000 rate, 14.231285 seconds, 98944 images
# Loaded: 0.000044 seconds
#
#  1547: 1.204741, 1.346683 avg loss, 0.001000 rate, 14.228477 seconds, 99008 images
# Loaded: 0.000032 seconds
#
#  1548: 1.076270, 1.319641 avg loss, 0.001000 rate, 14.193729 seconds, 99072 images
# Loaded: 0.000040 seconds
#
#  1549: 1.184477, 1.306125 avg loss, 0.001000 rate, 14.227989 seconds, 99136 images
# Loaded: 0.000053 seconds
#
#  1550: 1.202602, 1.295773 avg loss, 0.001000 rate, 14.173611 seconds, 99200 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.547897 seconds
#
#  1551: 1.528075, 1.319003 avg loss, 0.001000 rate, 10.339229 seconds, 99264 images
# Loaded: 0.000054 seconds
#
#  1552: 1.421505, 1.329253 avg loss, 0.001000 rate, 10.334635 seconds, 99328 images
# Loaded: 0.000033 seconds
#
#  1553: 1.245936, 1.320921 avg loss, 0.001000 rate, 10.338105 seconds, 99392 images
# Loaded: 0.000035 seconds
#
#  1554: 1.200602, 1.308890 avg loss, 0.001000 rate, 10.343228 seconds, 99456 images
# Loaded: 0.000046 seconds
#
#  1555: 1.645279, 1.342528 avg loss, 0.001000 rate, 10.389386 seconds, 99520 images
# Loaded: 0.000048 seconds
#
#  1556: 1.560563, 1.364332 avg loss, 0.001000 rate, 10.372832 seconds, 99584 images
# Loaded: 0.000045 seconds
#
#  1557: 1.275787, 1.355477 avg loss, 0.001000 rate, 10.353965 seconds, 99648 images
# Loaded: 0.000037 seconds
#
#  1558: 1.350527, 1.354982 avg loss, 0.001000 rate, 10.397247 seconds, 99712 images
# Loaded: 0.000039 seconds
#
#  1559: 1.343260, 1.353810 avg loss, 0.001000 rate, 10.356409 seconds, 99776 images
# Loaded: 0.000037 seconds
#
#  1560: 0.985916, 1.317021 avg loss, 0.001000 rate, 10.317502 seconds, 99840 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 0.478484 seconds
#
#  1561: 1.259107, 1.311229 avg loss, 0.001000 rate, 19.675514 seconds, 99904 images
# Loaded: 0.000057 seconds
#
#  1562: 1.334012, 1.313508 avg loss, 0.001000 rate, 19.801828 seconds, 99968 images
# Loaded: 0.000052 seconds
#
#  1563: 1.326897, 1.314847 avg loss, 0.001000 rate, 19.894362 seconds, 100032 images
# Loaded: 0.000069 seconds
#
#  1564: 1.670339, 1.350396 avg loss, 0.001000 rate, 19.837848 seconds, 100096 images
# Loaded: 0.000036 seconds
#
#  1565: 1.132551, 1.328611 avg loss, 0.001000 rate, 19.824034 seconds, 100160 images
# Loaded: 0.000040 seconds
#
#  1566: 1.101990, 1.305949 avg loss, 0.001000 rate, 19.796428 seconds, 100224 images
# Loaded: 0.000037 seconds
#
#  1567: 1.226498, 1.298004 avg loss, 0.001000 rate, 19.789030 seconds, 100288 images
# Loaded: 0.000057 seconds
#
#  1568: 1.360654, 1.304269 avg loss, 0.001000 rate, 19.706427 seconds, 100352 images
# Loaded: 0.000061 seconds
#
#  1569: 1.525815, 1.326424 avg loss, 0.001000 rate, 19.748773 seconds, 100416 images
# Loaded: 0.000037 seconds
#
#  1570: 1.714382, 1.365219 avg loss, 0.001000 rate, 19.783009 seconds, 100480 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 81.26 MB
#  CUDA allocate done!
# Loaded: 1.363786 seconds
#
#  1571: 1.127472, 1.341445 avg loss, 0.001000 rate, 15.489289 seconds, 100544 images
# Loaded: 0.000049 seconds
#
#  1572: 1.335365, 1.340837 avg loss, 0.001000 rate, 15.680895 seconds, 100608 images
# Loaded: 0.000038 seconds
#
#  1573: 1.225554, 1.329309 avg loss, 0.001000 rate, 15.615565 seconds, 100672 images
# Loaded: 0.000037 seconds
#
#  1574: 1.420821, 1.338460 avg loss, 0.001000 rate, 15.762070 seconds, 100736 images
# Loaded: 0.000066 seconds
#
#  1575: 1.422107, 1.346824 avg loss, 0.001000 rate, 15.636247 seconds, 100800 images
# Loaded: 0.000046 seconds
#
#  1576: 1.616628, 1.373805 avg loss, 0.001000 rate, 15.657669 seconds, 100864 images
# Loaded: 0.000042 seconds
#
#  1577: 1.391397, 1.375564 avg loss, 0.001000 rate, 15.606758 seconds, 100928 images
# Loaded: 0.000033 seconds
#
#  1578: 1.404489, 1.378457 avg loss, 0.001000 rate, 15.706275 seconds, 100992 images
# Loaded: 0.000059 seconds
#
#  1579: 1.597831, 1.400394 avg loss, 0.001000 rate, 15.606906 seconds, 101056 images
# Loaded: 0.000033 seconds
#
#  1580: 1.262602, 1.386615 avg loss, 0.001000 rate, 15.619545 seconds, 101120 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 81.26 MB
#  CUDA allocate done!
# Loaded: 1.262803 seconds
#
#  1581: 1.280747, 1.376028 avg loss, 0.001000 rate, 15.487153 seconds, 101184 images
# Loaded: 0.000049 seconds
#
#  1582: 1.495646, 1.387990 avg loss, 0.001000 rate, 15.682720 seconds, 101248 images
# Loaded: 0.000047 seconds
#
#  1583: 1.282071, 1.377398 avg loss, 0.001000 rate, 15.658110 seconds, 101312 images
# Loaded: 0.000042 seconds
#
#  1584: 1.050826, 1.344741 avg loss, 0.001000 rate, 15.660611 seconds, 101376 images
# Loaded: 0.000039 seconds
#
#  1585: 1.386104, 1.348877 avg loss, 0.001000 rate, 15.635325 seconds, 101440 images
# Loaded: 0.000040 seconds
#
#  1586: 1.454835, 1.359473 avg loss, 0.001000 rate, 15.784010 seconds, 101504 images
# Loaded: 0.000040 seconds
#
#  1587: 1.187423, 1.342268 avg loss, 0.001000 rate, 15.578866 seconds, 101568 images
# Loaded: 0.000039 seconds
#
#  1588: 1.265827, 1.334624 avg loss, 0.001000 rate, 15.665882 seconds, 101632 images
# Loaded: 0.000042 seconds
#
#  1589: 1.348963, 1.336058 avg loss, 0.001000 rate, 15.575774 seconds, 101696 images
# Loaded: 0.000049 seconds
#
#  1590: 1.516480, 1.354100 avg loss, 0.001000 rate, 15.603067 seconds, 101760 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.617316 seconds
#
#  1591: 1.539596, 1.372650 avg loss, 0.001000 rate, 7.678306 seconds, 101824 images
# Loaded: 0.000045 seconds
#
#  1592: 1.653311, 1.400716 avg loss, 0.001000 rate, 7.716795 seconds, 101888 images
# Loaded: 0.000034 seconds
#
#  1593: 1.504700, 1.411114 avg loss, 0.001000 rate, 7.750081 seconds, 101952 images
# Loaded: 0.000036 seconds
#
#  1594: 1.623199, 1.432323 avg loss, 0.001000 rate, 7.727554 seconds, 102016 images
# Loaded: 0.000035 seconds
#
#  1595: 1.377041, 1.426795 avg loss, 0.001000 rate, 7.725179 seconds, 102080 images
# Loaded: 0.000031 seconds
#
#  1596: 1.186046, 1.402720 avg loss, 0.001000 rate, 7.736358 seconds, 102144 images
# Loaded: 0.000045 seconds
#
#  1597: 0.997473, 1.362195 avg loss, 0.001000 rate, 7.717947 seconds, 102208 images
# Loaded: 0.000046 seconds
#
#  1598: 1.300929, 1.356068 avg loss, 0.001000 rate, 7.723576 seconds, 102272 images
# Loaded: 0.000038 seconds
#
#  1599: 1.562203, 1.376682 avg loss, 0.001000 rate, 7.744378 seconds, 102336 images
# Loaded: 0.000036 seconds
#
#  1600: 1.576320, 1.396646 avg loss, 0.000100 rate, 7.753432 seconds, 102400 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000038 seconds
#
#  1601: 1.156335, 1.372615 avg loss, 0.000100 rate, 10.227031 seconds, 102464 images
# Loaded: 0.000038 seconds
#
#  1602: 1.092124, 1.344566 avg loss, 0.000100 rate, 10.292830 seconds, 102528 images
# Loaded: 0.000042 seconds
#
#  1603: 1.265142, 1.336623 avg loss, 0.000100 rate, 10.340658 seconds, 102592 images
# Loaded: 0.000031 seconds
#
#  1604: 1.332085, 1.336169 avg loss, 0.000100 rate, 10.359559 seconds, 102656 images
# Loaded: 0.000043 seconds
#
#  1605: 1.289511, 1.331504 avg loss, 0.000100 rate, 10.381358 seconds, 102720 images
# Loaded: 0.000036 seconds
#
#  1606: 1.522590, 1.350612 avg loss, 0.000100 rate, 10.394926 seconds, 102784 images
# Loaded: 0.000039 seconds
#
#  1607: 1.363209, 1.351872 avg loss, 0.000100 rate, 10.372209 seconds, 102848 images
# Loaded: 0.000045 seconds
#
#  1608: 1.428522, 1.359537 avg loss, 0.000100 rate, 10.355079 seconds, 102912 images
# Loaded: 0.000038 seconds
#
#  1609: 1.499722, 1.373555 avg loss, 0.000100 rate, 10.322400 seconds, 102976 images
# Loaded: 0.000030 seconds
#
#  1610: 1.266082, 1.362808 avg loss, 0.000100 rate, 10.352228 seconds, 103040 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 0.000037 seconds
#
#  1611: 1.608055, 1.387333 avg loss, 0.000100 rate, 19.665996 seconds, 103104 images
# Loaded: 0.000056 seconds
#
#  1612: 1.330189, 1.381618 avg loss, 0.000100 rate, 19.879075 seconds, 103168 images
# Loaded: 0.000067 seconds
#
#  1613: 1.450903, 1.388547 avg loss, 0.000100 rate, 19.879804 seconds, 103232 images
# Loaded: 0.000063 seconds
#
#  1614: 1.168884, 1.366580 avg loss, 0.000100 rate, 19.853178 seconds, 103296 images
# Loaded: 0.000059 seconds
#
#  1615: 1.383236, 1.368246 avg loss, 0.000100 rate, 19.728871 seconds, 103360 images
# Loaded: 0.000105 seconds
#
#  1616: 1.203610, 1.351782 avg loss, 0.000100 rate, 19.718388 seconds, 103424 images
# Loaded: 0.000039 seconds
#
#  1617: 1.578365, 1.374441 avg loss, 0.000100 rate, 19.742617 seconds, 103488 images
# Loaded: 0.000054 seconds
#
#  1618: 1.481672, 1.385164 avg loss, 0.000100 rate, 19.777558 seconds, 103552 images
# Loaded: 0.000048 seconds
#
#  1619: 1.337556, 1.380403 avg loss, 0.000100 rate, 19.801831 seconds, 103616 images
# Loaded: 0.000039 seconds
#
#  1620: 1.290463, 1.371409 avg loss, 0.000100 rate, 19.785197 seconds, 103680 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.196940 seconds
#
#  1621: 1.740059, 1.408274 avg loss, 0.000100 rate, 7.076223 seconds, 103744 images
# Loaded: 0.000032 seconds
#
#  1622: 1.490383, 1.416485 avg loss, 0.000100 rate, 7.129484 seconds, 103808 images
# Loaded: 0.000034 seconds
#
#  1623: 1.562774, 1.431114 avg loss, 0.000100 rate, 7.176977 seconds, 103872 images
# Loaded: 0.000042 seconds
#
#  1624: 1.301372, 1.418140 avg loss, 0.000100 rate, 7.161743 seconds, 103936 images
# Loaded: 0.000032 seconds
#
#  1625: 1.356982, 1.412024 avg loss, 0.000100 rate, 7.181545 seconds, 104000 images
# Loaded: 0.000035 seconds
#
#  1626: 1.137061, 1.384528 avg loss, 0.000100 rate, 7.151967 seconds, 104064 images
# Loaded: 0.000036 seconds
#
#  1627: 1.143477, 1.360423 avg loss, 0.000100 rate, 7.142823 seconds, 104128 images
# Loaded: 0.000030 seconds
#
#  1628: 1.359417, 1.360322 avg loss, 0.000100 rate, 7.121921 seconds, 104192 images
# Loaded: 0.000036 seconds
#
#  1629: 1.474713, 1.371761 avg loss, 0.000100 rate, 7.168113 seconds, 104256 images
# Loaded: 0.000036 seconds
#
#  1630: 1.521938, 1.386779 avg loss, 0.000100 rate, 7.154905 seconds, 104320 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 0.000036 seconds
#
#  1631: 1.281286, 1.376230 avg loss, 0.000100 rate, 19.597075 seconds, 104384 images
# Loaded: 0.000049 seconds
#
#  1632: 1.181782, 1.356785 avg loss, 0.000100 rate, 19.817002 seconds, 104448 images
# Loaded: 0.000044 seconds
#
#  1633: 1.362508, 1.357357 avg loss, 0.000100 rate, 19.849708 seconds, 104512 images
# Loaded: 0.000046 seconds
#
#  1634: 1.444612, 1.366083 avg loss, 0.000100 rate, 19.841267 seconds, 104576 images
# Loaded: 0.000043 seconds
#
#  1635: 1.082758, 1.337750 avg loss, 0.000100 rate, 19.766620 seconds, 104640 images
# Loaded: 0.000044 seconds
#
#  1636: 1.518622, 1.355837 avg loss, 0.000100 rate, 19.833486 seconds, 104704 images
# Loaded: 0.000043 seconds
#
#  1637: 1.289597, 1.349213 avg loss, 0.000100 rate, 19.820639 seconds, 104768 images
# Loaded: 0.000049 seconds
#
#  1638: 1.453142, 1.359606 avg loss, 0.000100 rate, 19.733135 seconds, 104832 images
# Loaded: 0.000044 seconds
#
#  1639: 1.331979, 1.356843 avg loss, 0.000100 rate, 19.800429 seconds, 104896 images
# Loaded: 0.000029 seconds
#
#  1640: 1.733674, 1.394526 avg loss, 0.000100 rate, 19.809050 seconds, 104960 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 96.00 MB
#  CUDA allocate done!
# Loaded: 1.365827 seconds
#
#  1641: 1.516339, 1.406708 avg loss, 0.000100 rate, 18.486150 seconds, 105024 images
# Loaded: 0.000043 seconds
#
#  1642: 1.311046, 1.397142 avg loss, 0.000100 rate, 18.591415 seconds, 105088 images
# Loaded: 0.000043 seconds
#
#  1643: 1.485919, 1.406019 avg loss, 0.000100 rate, 18.678757 seconds, 105152 images
# Loaded: 0.000042 seconds
#
#  1644: 1.141139, 1.379531 avg loss, 0.000100 rate, 18.546749 seconds, 105216 images
# Loaded: 0.000043 seconds
#
#  1645: 1.199858, 1.361564 avg loss, 0.000100 rate, 18.570025 seconds, 105280 images
# Loaded: 0.000056 seconds
#
#  1646: 1.511973, 1.376605 avg loss, 0.000100 rate, 18.562443 seconds, 105344 images
# Loaded: 0.000056 seconds
#
#  1647: 1.130917, 1.352036 avg loss, 0.000100 rate, 18.463635 seconds, 105408 images
# Loaded: 0.000056 seconds
#
#  1648: 1.439239, 1.360756 avg loss, 0.000100 rate, 18.533860 seconds, 105472 images
# Loaded: 0.000051 seconds
#
#  1649: 1.442788, 1.368959 avg loss, 0.000100 rate, 18.511351 seconds, 105536 images
# Loaded: 0.000037 seconds
#
#  1650: 1.308277, 1.362891 avg loss, 0.000100 rate, 18.577275 seconds, 105600 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.614114 seconds
#
#  1651: 1.532164, 1.379818 avg loss, 0.000100 rate, 7.086731 seconds, 105664 images
# Loaded: 0.000036 seconds
#
#  1652: 1.392568, 1.381093 avg loss, 0.000100 rate, 7.181976 seconds, 105728 images
# Loaded: 0.000037 seconds
#
#  1653: 1.401697, 1.383154 avg loss, 0.000100 rate, 7.141708 seconds, 105792 images
# Loaded: 0.000038 seconds
#
#  1654: 1.678828, 1.412721 avg loss, 0.000100 rate, 7.212853 seconds, 105856 images
# Loaded: 0.000031 seconds
#
#  1655: 1.464632, 1.417912 avg loss, 0.000100 rate, 7.137838 seconds, 105920 images
# Loaded: 0.000029 seconds
#
#  1656: 1.605129, 1.436634 avg loss, 0.000100 rate, 7.153072 seconds, 105984 images
# Loaded: 0.000036 seconds
#
#  1657: 1.685144, 1.461485 avg loss, 0.000100 rate, 7.163115 seconds, 106048 images
# Loaded: 0.000032 seconds
#
#  1658: 1.234536, 1.438790 avg loss, 0.000100 rate, 7.138441 seconds, 106112 images
# Loaded: 0.000044 seconds
#
#  1659: 1.535983, 1.448509 avg loss, 0.000100 rate, 7.159534 seconds, 106176 images
# Loaded: 0.000032 seconds
#
#  1660: 1.267430, 1.430401 avg loss, 0.000100 rate, 7.164276 seconds, 106240 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000042 seconds
#
#  1661: 1.554576, 1.442819 avg loss, 0.000100 rate, 9.539719 seconds, 106304 images
# Loaded: 0.000037 seconds
#
#  1662: 1.248924, 1.423429 avg loss, 0.000100 rate, 9.590952 seconds, 106368 images
# Loaded: 0.000041 seconds
#
#  1663: 1.049603, 1.386047 avg loss, 0.000100 rate, 9.618409 seconds, 106432 images
# Loaded: 0.000032 seconds
#
#  1664: 1.190164, 1.366458 avg loss, 0.000100 rate, 9.639798 seconds, 106496 images
# Loaded: 0.000037 seconds
#
#  1665: 1.455351, 1.375348 avg loss, 0.000100 rate, 9.612078 seconds, 106560 images
# Loaded: 0.000036 seconds
#
#  1666: 1.163127, 1.354125 avg loss, 0.000100 rate, 9.654792 seconds, 106624 images
# Loaded: 0.000044 seconds
#
#  1667: 1.394362, 1.358149 avg loss, 0.000100 rate, 9.628048 seconds, 106688 images
# Loaded: 0.000053 seconds
#
#  1668: 1.182408, 1.340575 avg loss, 0.000100 rate, 9.608436 seconds, 106752 images
# Loaded: 0.000036 seconds
#
#  1669: 1.394161, 1.345934 avg loss, 0.000100 rate, 9.639872 seconds, 106816 images
# Loaded: 0.000037 seconds
#
#  1670: 1.305502, 1.341891 avg loss, 0.000100 rate, 9.633752 seconds, 106880 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.044211 seconds
#
#  1671: 1.863406, 1.394042 avg loss, 0.000100 rate, 7.661295 seconds, 106944 images
# Loaded: 0.000033 seconds
#
#  1672: 0.884017, 1.343040 avg loss, 0.000100 rate, 7.689979 seconds, 107008 images
# Loaded: 0.000038 seconds
#
#  1673: 1.446045, 1.353340 avg loss, 0.000100 rate, 7.717368 seconds, 107072 images
# Loaded: 0.000037 seconds
#
#  1674: 1.384154, 1.356421 avg loss, 0.000100 rate, 7.738573 seconds, 107136 images
# Loaded: 0.000038 seconds
#
#  1675: 1.276290, 1.348408 avg loss, 0.000100 rate, 7.730085 seconds, 107200 images
# Loaded: 0.000036 seconds
#
#  1676: 1.370316, 1.350599 avg loss, 0.000100 rate, 7.730316 seconds, 107264 images
# Loaded: 0.000048 seconds
#
#  1677: 1.479026, 1.363442 avg loss, 0.000100 rate, 7.714096 seconds, 107328 images
# Loaded: 0.000035 seconds
#
#  1678: 1.257445, 1.352842 avg loss, 0.000100 rate, 7.744103 seconds, 107392 images
# Loaded: 0.000033 seconds
#
#  1679: 1.324731, 1.350031 avg loss, 0.000100 rate, 7.749493 seconds, 107456 images
# Loaded: 0.000044 seconds
#
#  1680: 0.993289, 1.314357 avg loss, 0.000100 rate, 7.712208 seconds, 107520 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000043 seconds
#
#  1681: 1.254017, 1.308323 avg loss, 0.000100 rate, 10.294430 seconds, 107584 images
# Loaded: 0.000043 seconds
#
#  1682: 1.173298, 1.294820 avg loss, 0.000100 rate, 10.387895 seconds, 107648 images
# Loaded: 0.000044 seconds
#
#  1683: 1.272416, 1.292580 avg loss, 0.000100 rate, 10.363799 seconds, 107712 images
# Loaded: 0.000039 seconds
#
#  1684: 0.942787, 1.257601 avg loss, 0.000100 rate, 10.397902 seconds, 107776 images
# Loaded: 0.000046 seconds
#
#  1685: 1.371884, 1.269029 avg loss, 0.000100 rate, 10.361796 seconds, 107840 images
# Loaded: 0.000036 seconds
#
#  1686: 1.309301, 1.273056 avg loss, 0.000100 rate, 10.387421 seconds, 107904 images
# Loaded: 0.000034 seconds
#
#  1687: 1.356985, 1.281449 avg loss, 0.000100 rate, 10.421895 seconds, 107968 images
# Loaded: 0.000035 seconds
#
#  1688: 0.893081, 1.242612 avg loss, 0.000100 rate, 10.344405 seconds, 108032 images
# Loaded: 0.000051 seconds
#
#  1689: 1.572481, 1.275599 avg loss, 0.000100 rate, 10.418167 seconds, 108096 images
# Loaded: 0.000035 seconds
#
#  1690: 1.150398, 1.263079 avg loss, 0.000100 rate, 10.362680 seconds, 108160 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.146789 seconds
#
#  1691: 1.402754, 1.277046 avg loss, 0.000100 rate, 10.286042 seconds, 108224 images
# Loaded: 0.000035 seconds
#
#  1692: 1.101795, 1.259521 avg loss, 0.000100 rate, 10.325658 seconds, 108288 images
# Loaded: 0.000035 seconds
#
#  1693: 1.263423, 1.259911 avg loss, 0.000100 rate, 10.403472 seconds, 108352 images
# Loaded: 0.000036 seconds
#
#  1694: 1.289479, 1.262868 avg loss, 0.000100 rate, 10.362773 seconds, 108416 images
# Loaded: 0.000038 seconds
#
#  1695: 1.282186, 1.264800 avg loss, 0.000100 rate, 10.339573 seconds, 108480 images
# Loaded: 0.000036 seconds
#
#  1696: 1.181691, 1.256489 avg loss, 0.000100 rate, 10.353578 seconds, 108544 images
# Loaded: 0.000034 seconds
#
#  1697: 0.960477, 1.226888 avg loss, 0.000100 rate, 10.350879 seconds, 108608 images
# Loaded: 0.000039 seconds
#
#  1698: 0.940004, 1.198199 avg loss, 0.000100 rate, 10.352352 seconds, 108672 images
# Loaded: 0.000035 seconds
#
#  1699: 1.163373, 1.194717 avg loss, 0.000100 rate, 10.378118 seconds, 108736 images
# Loaded: 0.000036 seconds
#
#  1700: 0.850073, 1.160252 avg loss, 0.000100 rate, 10.331491 seconds, 108800 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 0.000044 seconds
#
#  1701: 1.402173, 1.184444 avg loss, 0.000100 rate, 19.730156 seconds, 108864 images
# Loaded: 0.000045 seconds
#
#  1702: 1.414962, 1.207496 avg loss, 0.000100 rate, 19.914309 seconds, 108928 images
# Loaded: 0.000043 seconds
#
#  1703: 1.271229, 1.213869 avg loss, 0.000100 rate, 19.858218 seconds, 108992 images
# Loaded: 0.000031 seconds
#
#  1704: 1.531117, 1.245594 avg loss, 0.000100 rate, 19.948649 seconds, 109056 images
# Loaded: 0.000078 seconds
#
#  1705: 1.204543, 1.241489 avg loss, 0.000100 rate, 19.772606 seconds, 109120 images
# Loaded: 0.000060 seconds
#
#  1706: 1.068624, 1.224203 avg loss, 0.000100 rate, 19.747400 seconds, 109184 images
# Loaded: 0.000037 seconds
#
#  1707: 1.086908, 1.210473 avg loss, 0.000100 rate, 19.784489 seconds, 109248 images
# Loaded: 0.000051 seconds
#
#  1708: 1.233949, 1.212821 avg loss, 0.000100 rate, 19.823941 seconds, 109312 images
# Loaded: 0.000037 seconds
#
#  1709: 0.941372, 1.185676 avg loss, 0.000100 rate, 19.685813 seconds, 109376 images
# Loaded: 0.000056 seconds
#
#  1710: 1.060508, 1.173159 avg loss, 0.000100 rate, 19.741949 seconds, 109440 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000066 seconds
#
#  1711: 1.456000, 1.201443 avg loss, 0.000100 rate, 7.642345 seconds, 109504 images
# Loaded: 0.000037 seconds
#
#  1712: 1.496591, 1.230958 avg loss, 0.000100 rate, 7.719729 seconds, 109568 images
# Loaded: 0.000029 seconds
#
#  1713: 1.559284, 1.263791 avg loss, 0.000100 rate, 7.722987 seconds, 109632 images
# Loaded: 0.000037 seconds
#
#  1714: 1.719407, 1.309352 avg loss, 0.000100 rate, 7.760603 seconds, 109696 images
# Loaded: 0.000033 seconds
#
#  1715: 1.558969, 1.334314 avg loss, 0.000100 rate, 7.701785 seconds, 109760 images
# Loaded: 0.000043 seconds
#
#  1716: 1.099146, 1.310797 avg loss, 0.000100 rate, 7.732723 seconds, 109824 images
# Loaded: 0.000033 seconds
#
#  1717: 1.398292, 1.319546 avg loss, 0.000100 rate, 7.701571 seconds, 109888 images
# Loaded: 0.000037 seconds
#
#  1718: 1.235333, 1.311125 avg loss, 0.000100 rate, 7.721413 seconds, 109952 images
# Loaded: 0.000043 seconds
#
#  1719: 1.170209, 1.297034 avg loss, 0.000100 rate, 7.710028 seconds, 110016 images
# Loaded: 0.000031 seconds
#
#  1720: 1.157822, 1.283112 avg loss, 0.000100 rate, 7.689120 seconds, 110080 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 55.45 MB
#  CUDA allocate done!
# Loaded: 0.000034 seconds
#
#  1721: 1.175100, 1.272311 avg loss, 0.000100 rate, 11.073276 seconds, 110144 images
# Loaded: 0.000034 seconds
#
#  1722: 1.224474, 1.267527 avg loss, 0.000100 rate, 11.214154 seconds, 110208 images
# Loaded: 0.000035 seconds
#
#  1723: 1.243362, 1.265111 avg loss, 0.000100 rate, 11.205528 seconds, 110272 images
# Loaded: 0.000038 seconds
#
#  1724: 1.206329, 1.259233 avg loss, 0.000100 rate, 11.198704 seconds, 110336 images
# Loaded: 0.000037 seconds
#
#  1725: 1.293015, 1.262611 avg loss, 0.000100 rate, 11.178032 seconds, 110400 images
# Loaded: 0.000038 seconds
#
#  1726: 1.162188, 1.252569 avg loss, 0.000100 rate, 11.172610 seconds, 110464 images
# Loaded: 0.000037 seconds
#
#  1727: 1.259109, 1.253223 avg loss, 0.000100 rate, 11.196202 seconds, 110528 images
# Loaded: 0.000044 seconds
#
#  1728: 0.886899, 1.216590 avg loss, 0.000100 rate, 11.161451 seconds, 110592 images
# Loaded: 0.000036 seconds
#
#  1729: 1.534663, 1.248398 avg loss, 0.000100 rate, 11.226069 seconds, 110656 images
# Loaded: 0.000033 seconds
#
#  1730: 1.252767, 1.248835 avg loss, 0.000100 rate, 11.184071 seconds, 110720 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.994332 seconds
#
#  1731: 1.004938, 1.224445 avg loss, 0.000100 rate, 7.051252 seconds, 110784 images
# Loaded: 0.000033 seconds
#
#  1732: 1.439617, 1.245962 avg loss, 0.000100 rate, 7.160684 seconds, 110848 images
# Loaded: 0.000043 seconds
#
#  1733: 1.493953, 1.270761 avg loss, 0.000100 rate, 7.170672 seconds, 110912 images
# Loaded: 0.000042 seconds
#
#  1734: 1.334233, 1.277108 avg loss, 0.000100 rate, 7.158297 seconds, 110976 images
# Loaded: 0.000037 seconds
#
#  1735: 1.703770, 1.319775 avg loss, 0.000100 rate, 7.174277 seconds, 111040 images
# Loaded: 0.000045 seconds
#
#  1736: 1.393766, 1.327174 avg loss, 0.000100 rate, 7.152236 seconds, 111104 images
# Loaded: 0.000033 seconds
#
#  1737: 0.862634, 1.280720 avg loss, 0.000100 rate, 7.136971 seconds, 111168 images
# Loaded: 0.000054 seconds
#
#  1738: 1.000527, 1.252700 avg loss, 0.000100 rate, 7.153253 seconds, 111232 images
# Loaded: 0.000037 seconds
#
#  1739: 1.633766, 1.290807 avg loss, 0.000100 rate, 7.199561 seconds, 111296 images
# Loaded: 0.000044 seconds
#
#  1740: 1.458357, 1.307562 avg loss, 0.000100 rate, 7.167076 seconds, 111360 images
# Resizing
# 768 x 768
#  try to allocate additional workspace_size = 88.48 MB
#  CUDA allocate done!
# Loaded: 0.000039 seconds
#
#  1741: 1.687687, 1.345574 avg loss, 0.000100 rate, 16.616512 seconds, 111424 images
# Loaded: 0.000070 seconds
#
#  1742: 1.139530, 1.324970 avg loss, 0.000100 rate, 16.676765 seconds, 111488 images
# Loaded: 0.000048 seconds
#
# ...
# Loaded: 0.000035 seconds
#
#  2870: 1.346668, 1.258056 avg loss, 0.000010 rate, 11.996015 seconds, 183680 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.148314 seconds
#
#  2871: 1.379411, 1.270191 avg loss, 0.000010 rate, 7.656184 seconds, 183744 images
# Loaded: 0.000037 seconds
#
#  2872: 1.226903, 1.265863 avg loss, 0.000010 rate, 7.731556 seconds, 183808 images
# Loaded: 0.000035 seconds
#
#  2873: 1.343918, 1.273668 avg loss, 0.000010 rate, 7.754356 seconds, 183872 images
# Loaded: 0.000052 seconds
#
#  2874: 1.715555, 1.317857 avg loss, 0.000010 rate, 7.780387 seconds, 183936 images
# Loaded: 0.000063 seconds
#
#  2875: 1.345763, 1.320647 avg loss, 0.000010 rate, 7.748861 seconds, 184000 images
# Loaded: 0.000038 seconds
#
#  2876: 1.498968, 1.338480 avg loss, 0.000010 rate, 7.772093 seconds, 184064 images
# Loaded: 0.000040 seconds
#
#  2877: 1.249466, 1.329578 avg loss, 0.000010 rate, 7.743630 seconds, 184128 images
# Loaded: 0.000051 seconds
#
#  2878: 1.177914, 1.314412 avg loss, 0.000010 rate, 7.765334 seconds, 184192 images
# Loaded: 0.000040 seconds
#
#  2879: 1.038034, 1.286774 avg loss, 0.000010 rate, 7.736336 seconds, 184256 images
# Loaded: 0.000037 seconds
#
#  2880: 0.907514, 1.248848 avg loss, 0.000010 rate, 7.708125 seconds, 184320 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 0.000064 seconds
#
#  2881: 1.335056, 1.257469 avg loss, 0.000010 rate, 19.751222 seconds, 184384 images
# Loaded: 0.000043 seconds
#
#  2882: 1.159454, 1.247667 avg loss, 0.000010 rate, 19.849284 seconds, 184448 images
# Loaded: 0.000063 seconds
#
#  2883: 1.113939, 1.234295 avg loss, 0.000010 rate, 19.863334 seconds, 184512 images
# Loaded: 0.000040 seconds
#
#  2884: 1.183002, 1.229165 avg loss, 0.000010 rate, 19.859498 seconds, 184576 images
# Loaded: 0.000041 seconds
#
#  2885: 1.120144, 1.218263 avg loss, 0.000010 rate, 19.783876 seconds, 184640 images
# Loaded: 0.000057 seconds
#
#  2886: 1.216760, 1.218113 avg loss, 0.000010 rate, 19.853000 seconds, 184704 images
# Loaded: 0.000041 seconds
#
#  2887: 1.221870, 1.218489 avg loss, 0.000010 rate, 19.860172 seconds, 184768 images
# Loaded: 0.000047 seconds
#
#  2888: 1.279703, 1.224610 avg loss, 0.000010 rate, 19.822308 seconds, 184832 images
# Loaded: 0.000037 seconds
#
#  2889: 1.247945, 1.226944 avg loss, 0.000010 rate, 19.818375 seconds, 184896 images
# Loaded: 0.000059 seconds
#
#  2890: 1.303466, 1.234596 avg loss, 0.000010 rate, 19.746706 seconds, 184960 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000051 seconds
#
#  2891: 1.468475, 1.257984 avg loss, 0.000010 rate, 10.283788 seconds, 185024 images
# Loaded: 0.000044 seconds
#
#  2892: 1.341392, 1.266325 avg loss, 0.000010 rate, 10.354155 seconds, 185088 images
# Loaded: 0.000048 seconds
#
#  2893: 1.018946, 1.241587 avg loss, 0.000010 rate, 10.348523 seconds, 185152 images
# Loaded: 0.000052 seconds
#
#  2894: 1.168015, 1.234230 avg loss, 0.000010 rate, 10.341465 seconds, 185216 images
# Loaded: 0.000051 seconds
#
#  2895: 1.090697, 1.219876 avg loss, 0.000010 rate, 10.349262 seconds, 185280 images
# Loaded: 0.000042 seconds
#
#  2896: 1.226760, 1.220565 avg loss, 0.000010 rate, 10.396993 seconds, 185344 images
# Loaded: 0.000053 seconds
#
#  2897: 1.292105, 1.227719 avg loss, 0.000010 rate, 10.393658 seconds, 185408 images
# Loaded: 0.000034 seconds
#
#  2898: 1.276988, 1.232646 avg loss, 0.000010 rate, 10.406101 seconds, 185472 images
# Loaded: 0.000036 seconds
#
#  2899: 1.345387, 1.243920 avg loss, 0.000010 rate, 10.422558 seconds, 185536 images
# Loaded: 0.000056 seconds
#
#  2900: 1.253740, 1.244902 avg loss, 0.000010 rate, 10.416920 seconds, 185600 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 81.26 MB
#  CUDA allocate done!
# Loaded: 0.000036 seconds
#
#  2901: 1.347081, 1.255120 avg loss, 0.000010 rate, 15.647026 seconds, 185664 images
# Loaded: 0.000065 seconds
#
#  2902: 1.294743, 1.259082 avg loss, 0.000010 rate, 15.701050 seconds, 185728 images
# Loaded: 0.000044 seconds
#
#  2903: 1.580307, 1.291205 avg loss, 0.000010 rate, 15.863954 seconds, 185792 images
# Loaded: 0.000042 seconds
#
#  2904: 1.041121, 1.266196 avg loss, 0.000010 rate, 15.682527 seconds, 185856 images
# Loaded: 0.000060 seconds
#
#  2905: 1.183107, 1.257887 avg loss, 0.000010 rate, 15.600568 seconds, 185920 images
# Loaded: 0.000072 seconds
#
#  2906: 1.066660, 1.238765 avg loss, 0.000010 rate, 15.589020 seconds, 185984 images
# Loaded: 0.000066 seconds
#
#  2907: 0.912742, 1.206162 avg loss, 0.000010 rate, 15.560103 seconds, 186048 images
# Loaded: 0.000056 seconds
#
#  2908: 1.086404, 1.194186 avg loss, 0.000010 rate, 15.621601 seconds, 186112 images
# Loaded: 0.000042 seconds
#
#  2909: 1.405475, 1.215315 avg loss, 0.000010 rate, 15.669479 seconds, 186176 images
# Loaded: 0.000040 seconds
#
#  2910: 1.186891, 1.212473 avg loss, 0.000010 rate, 15.622557 seconds, 186240 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.195881 seconds
#
#  2911: 1.217753, 1.213001 avg loss, 0.000010 rate, 7.617434 seconds, 186304 images
# Loaded: 0.000040 seconds
#
#  2912: 1.325318, 1.224233 avg loss, 0.000010 rate, 7.704503 seconds, 186368 images
# Loaded: 0.000034 seconds
#
#  2913: 1.104887, 1.212298 avg loss, 0.000010 rate, 7.733335 seconds, 186432 images
# Loaded: 0.000058 seconds
#
#  2914: 1.495895, 1.240658 avg loss, 0.000010 rate, 7.774703 seconds, 186496 images
# Loaded: 0.000039 seconds
#
#  2915: 1.234490, 1.240041 avg loss, 0.000010 rate, 7.739602 seconds, 186560 images
# Loaded: 0.000037 seconds
#
#  2916: 1.526088, 1.268646 avg loss, 0.000010 rate, 7.774794 seconds, 186624 images
# Loaded: 0.000039 seconds
#
#  2917: 1.428297, 1.284611 avg loss, 0.000010 rate, 7.736921 seconds, 186688 images
# Loaded: 0.000035 seconds
#
#  2918: 1.299544, 1.286104 avg loss, 0.000010 rate, 7.780076 seconds, 186752 images
# Loaded: 0.000044 seconds
#
#  2919: 1.336773, 1.291171 avg loss, 0.000010 rate, 7.778868 seconds, 186816 images
# Loaded: 0.000033 seconds
#
#  2920: 1.046471, 1.266701 avg loss, 0.000010 rate, 7.729907 seconds, 186880 images
# Resizing
# 640 x 640
#  try to allocate additional workspace_size = 61.44 MB
#  CUDA allocate done!
# Loaded: 0.000044 seconds
#
#  2921: 1.279357, 1.267967 avg loss, 0.000010 rate, 11.884570 seconds, 186944 images
# Loaded: 0.000046 seconds
#
#  2922: 1.161377, 1.257308 avg loss, 0.000010 rate, 11.965096 seconds, 187008 images
# Loaded: 0.000041 seconds
#
#  2923: 1.056849, 1.237262 avg loss, 0.000010 rate, 11.983377 seconds, 187072 images
# Loaded: 0.000039 seconds
#
#  2924: 1.297112, 1.243247 avg loss, 0.000010 rate, 11.987727 seconds, 187136 images
# Loaded: 0.000052 seconds
#
#  2925: 1.097337, 1.228656 avg loss, 0.000010 rate, 11.988251 seconds, 187200 images
# Loaded: 0.000072 seconds
#
#  2926: 1.199919, 1.225782 avg loss, 0.000010 rate, 12.002567 seconds, 187264 images
# Loaded: 0.000037 seconds
#
#  2927: 1.244475, 1.227651 avg loss, 0.000010 rate, 11.992918 seconds, 187328 images
# Loaded: 0.000042 seconds
#
#  2928: 0.991066, 1.203993 avg loss, 0.000010 rate, 12.038958 seconds, 187392 images
# Loaded: 0.000036 seconds
#
#  2929: 0.948344, 1.178428 avg loss, 0.000010 rate, 11.977797 seconds, 187456 images
# Loaded: 0.000036 seconds
#
#  2930: 1.279540, 1.188539 avg loss, 0.000010 rate, 12.005237 seconds, 187520 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 96.00 MB
#  CUDA allocate done!
# Loaded: 0.000040 seconds
#
#  2931: 1.356688, 1.205354 avg loss, 0.000010 rate, 18.586105 seconds, 187584 images
# Loaded: 0.000038 seconds
#
#  2932: 1.226011, 1.207420 avg loss, 0.000010 rate, 18.679979 seconds, 187648 images
# Loaded: 0.000046 seconds
#
#  2933: 1.065626, 1.193241 avg loss, 0.000010 rate, 18.560639 seconds, 187712 images
# Loaded: 0.000060 seconds
#
#  2934: 1.239048, 1.197821 avg loss, 0.000010 rate, 18.656850 seconds, 187776 images
# Loaded: 0.000041 seconds
#
#  2935: 1.252558, 1.203295 avg loss, 0.000010 rate, 18.567674 seconds, 187840 images
# Loaded: 0.000051 seconds
#
#  2936: 1.057293, 1.188695 avg loss, 0.000010 rate, 18.632041 seconds, 187904 images
# Loaded: 0.000037 seconds
#
#  2937: 1.036001, 1.173425 avg loss, 0.000010 rate, 18.696312 seconds, 187968 images
# Loaded: 0.000049 seconds
#
#  2938: 1.070335, 1.163116 avg loss, 0.000010 rate, 18.570154 seconds, 188032 images
# Loaded: 0.000055 seconds
#
#  2939: 0.926826, 1.139487 avg loss, 0.000010 rate, 18.523725 seconds, 188096 images
# Loaded: 0.000071 seconds
#
#  2940: 1.413682, 1.166907 avg loss, 0.000010 rate, 18.662922 seconds, 188160 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000057 seconds
#
#  2941: 1.382143, 1.188430 avg loss, 0.000010 rate, 7.646818 seconds, 188224 images
# Loaded: 0.000048 seconds
#
#  2942: 1.239131, 1.193500 avg loss, 0.000010 rate, 7.708078 seconds, 188288 images
# Loaded: 0.000040 seconds
#
#  2943: 1.149503, 1.189101 avg loss, 0.000010 rate, 7.729173 seconds, 188352 images
# Loaded: 0.000040 seconds
#
#  2944: 1.180738, 1.188264 avg loss, 0.000010 rate, 7.712290 seconds, 188416 images
# Loaded: 0.000041 seconds
#
#  2945: 1.411554, 1.210593 avg loss, 0.000010 rate, 7.729637 seconds, 188480 images
# Loaded: 0.000043 seconds
#
#  2946: 1.352712, 1.224805 avg loss, 0.000010 rate, 7.717315 seconds, 188544 images
# Loaded: 0.000047 seconds
#
#  2947: 1.043421, 1.206667 avg loss, 0.000010 rate, 7.686453 seconds, 188608 images
# Loaded: 0.000035 seconds
#
#  2948: 1.231144, 1.209115 avg loss, 0.000010 rate, 7.759442 seconds, 188672 images
# Loaded: 0.000049 seconds
#
#  2949: 1.212260, 1.209429 avg loss, 0.000010 rate, 7.699336 seconds, 188736 images
# Loaded: 0.000039 seconds
#
#  2950: 1.156575, 1.204144 avg loss, 0.000010 rate, 7.697006 seconds, 188800 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.032734 seconds
#
#  2951: 1.147443, 1.198474 avg loss, 0.000010 rate, 9.540602 seconds, 188864 images
# Loaded: 0.000040 seconds
#
#  2952: 1.281889, 1.206815 avg loss, 0.000010 rate, 9.604523 seconds, 188928 images
# Loaded: 0.000038 seconds
#
#  2953: 1.159627, 1.202096 avg loss, 0.000010 rate, 9.612410 seconds, 188992 images
# Loaded: 0.000037 seconds
#
#  2954: 1.080949, 1.189982 avg loss, 0.000010 rate, 9.624161 seconds, 189056 images
# Loaded: 0.000040 seconds
#
#  2955: 1.080107, 1.178994 avg loss, 0.000010 rate, 9.617178 seconds, 189120 images
# Loaded: 0.000041 seconds
#
#  2956: 1.147990, 1.175894 avg loss, 0.000010 rate, 9.624285 seconds, 189184 images
# Loaded: 0.000041 seconds
#
#  2957: 1.135892, 1.171894 avg loss, 0.000010 rate, 9.645445 seconds, 189248 images
# Loaded: 0.000036 seconds
#
#  2958: 0.946469, 1.149351 avg loss, 0.000010 rate, 9.615012 seconds, 189312 images
# Loaded: 0.000040 seconds
#
#  2959: 1.120354, 1.146451 avg loss, 0.000010 rate, 9.639196 seconds, 189376 images
# Loaded: 0.000042 seconds
#
#  2960: 0.908813, 1.122688 avg loss, 0.000010 rate, 9.593231 seconds, 189440 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.002569 seconds
#
#  2961: 1.404479, 1.150867 avg loss, 0.000010 rate, 10.306135 seconds, 189504 images
# Loaded: 0.000040 seconds
#
#  2962: 1.168297, 1.152610 avg loss, 0.000010 rate, 10.407868 seconds, 189568 images
# Loaded: 0.000043 seconds
#
#  2963: 1.328349, 1.170184 avg loss, 0.000010 rate, 10.401821 seconds, 189632 images
# Loaded: 0.000040 seconds
#
#  2964: 1.242462, 1.177412 avg loss, 0.000010 rate, 10.356546 seconds, 189696 images
# Loaded: 0.000035 seconds
#
#  2965: 0.952045, 1.154875 avg loss, 0.000010 rate, 10.346542 seconds, 189760 images
# Loaded: 0.000046 seconds
#
#  2966: 1.116673, 1.151055 avg loss, 0.000010 rate, 10.358914 seconds, 189824 images
# Loaded: 0.000039 seconds
#
#  2967: 1.161957, 1.152145 avg loss, 0.000010 rate, 10.375258 seconds, 189888 images
# Loaded: 0.000037 seconds
#
#  2968: 1.002784, 1.137209 avg loss, 0.000010 rate, 10.345563 seconds, 189952 images
# Loaded: 0.000038 seconds
#
#  2969: 1.005244, 1.124012 avg loss, 0.000010 rate, 10.329475 seconds, 190016 images
# Loaded: 0.000044 seconds
#
#  2970: 1.110220, 1.122633 avg loss, 0.000010 rate, 10.385655 seconds, 190080 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.016814 seconds
#
#  2971: 1.341305, 1.144500 avg loss, 0.000010 rate, 7.093710 seconds, 190144 images
# Loaded: 0.000033 seconds
#
#  2972: 1.482742, 1.178325 avg loss, 0.000010 rate, 7.163671 seconds, 190208 images
# Loaded: 0.000036 seconds
#
#  2973: 1.409201, 1.201412 avg loss, 0.000010 rate, 7.196595 seconds, 190272 images
# Loaded: 0.000038 seconds
#
#  2974: 1.133130, 1.194584 avg loss, 0.000010 rate, 7.146263 seconds, 190336 images
# Loaded: 0.000040 seconds
#
#  2975: 1.345429, 1.209669 avg loss, 0.000010 rate, 7.174852 seconds, 190400 images
# Loaded: 0.000034 seconds
#
#  2976: 1.277572, 1.216459 avg loss, 0.000010 rate, 7.164166 seconds, 190464 images
# Loaded: 0.000075 seconds
#
#  2977: 1.036963, 1.198509 avg loss, 0.000010 rate, 7.160191 seconds, 190528 images
# Loaded: 0.000039 seconds
#
#  2978: 1.052004, 1.183859 avg loss, 0.000010 rate, 7.190924 seconds, 190592 images
# Loaded: 0.000046 seconds
#
#  2979: 1.274086, 1.192881 avg loss, 0.000010 rate, 7.171915 seconds, 190656 images
# Loaded: 0.000035 seconds
#
#  2980: 1.239908, 1.197584 avg loss, 0.000010 rate, 7.165962 seconds, 190720 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 0.000035 seconds
#
#  2981: 1.089835, 1.186809 avg loss, 0.000010 rate, 19.721790 seconds, 190784 images
# Loaded: 0.000053 seconds
#
#  2982: 1.441920, 1.212320 avg loss, 0.000010 rate, 19.985043 seconds, 190848 images
# Loaded: 0.000047 seconds
#
#  2983: 1.187602, 1.209849 avg loss, 0.000010 rate, 19.856768 seconds, 190912 images
# Loaded: 0.000050 seconds
#
#  2984: 1.495056, 1.238369 avg loss, 0.000010 rate, 19.817988 seconds, 190976 images
# Loaded: 0.000058 seconds
#
#  2985: 1.025763, 1.217109 avg loss, 0.000010 rate, 19.796930 seconds, 191040 images
# Loaded: 0.000049 seconds
#
#  2986: 1.162576, 1.211655 avg loss, 0.000010 rate, 19.768949 seconds, 191104 images
# Loaded: 0.000052 seconds
#
#  2987: 1.258803, 1.216370 avg loss, 0.000010 rate, 19.744172 seconds, 191168 images
# Loaded: 0.000056 seconds
#
#  2988: 1.392166, 1.233950 avg loss, 0.000010 rate, 19.831144 seconds, 191232 images
# Loaded: 0.000038 seconds
#
#  2989: 1.160887, 1.226644 avg loss, 0.000010 rate, 19.773820 seconds, 191296 images
# Loaded: 0.000049 seconds
#
#  2990: 1.034958, 1.207475 avg loss, 0.000010 rate, 19.722902 seconds, 191360 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000043 seconds
#
#  2991: 0.937637, 1.180491 avg loss, 0.000010 rate, 7.601893 seconds, 191424 images
# Loaded: 0.000038 seconds
#
#  2992: 1.185429, 1.180985 avg loss, 0.000010 rate, 7.729329 seconds, 191488 images
# Loaded: 0.000044 seconds
#
#  2993: 1.168252, 1.179712 avg loss, 0.000010 rate, 7.746204 seconds, 191552 images
# Loaded: 0.000038 seconds
#
#  2994: 1.144088, 1.176149 avg loss, 0.000010 rate, 7.705482 seconds, 191616 images
# Loaded: 0.000042 seconds
#
#  2995: 1.506176, 1.209152 avg loss, 0.000010 rate, 7.737925 seconds, 191680 images
# Loaded: 0.000037 seconds
#
#  2996: 1.189122, 1.207149 avg loss, 0.000010 rate, 7.711820 seconds, 191744 images
# Loaded: 0.000035 seconds
#
#  2997: 1.463054, 1.232739 avg loss, 0.000010 rate, 7.731457 seconds, 191808 images
# Loaded: 0.000032 seconds
#
#  2998: 1.642659, 1.273731 avg loss, 0.000010 rate, 7.759106 seconds, 191872 images
# Loaded: 0.000038 seconds
#
#  2999: 0.905328, 1.236891 avg loss, 0.000010 rate, 7.709246 seconds, 191936 images
# Loaded: 0.000039 seconds
#
#  3000: 1.335870, 1.246789 avg loss, 0.000010 rate, 7.674374 seconds, 192000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_3000.weights
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_last.weights
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-voc_final.weights

# %% [markdown]
# ## TROUBLESHOOTING
# The main problems you can face if your model throw an error is:
#
# * Images or files not found. Check the **Yolov3 cheat sheet** image above and check that everything is ok.
# * If have you configured wrongly your **filters** and **classes** in the **yolov3.cfg**. Check the **Yolov3 cheet sheet** above.
# * You can face some out of memory or library errors mainly for the lack of some the pre-requisits. In this case, check the versions of the current libraries installed on your Colab VM. You can find more information in the first steps of this notebook.
# * **Batch** and **subdivisions** parameters on your **yolov3.cfg** can affect to the memory allocation as well. Refer to the original repo [Here]() for further details.

# %% [markdown]
# ## About me
#
# You can find the original post with more explanations about this notebook at [How to train YOLOv3 using Darknet framework and optimize the VM runtime load times](post link)
#
# I'm David Ibañez from Barcelona. Feel free to get in touch!
#
# * You can visit my blog at [Dev-ibanyez.info](http://blog.ibanyex.info)
# * You can get in touch with me on [Twitter](https://twitter.com/dav_ibanez)
# * You can get in touch or contribute to this notebook at [Github](https://github.com/kriyeng/yolo-on-colab-notebook/)
# * You can comment on the [dev.to post about this notebook ](PENDING)
#
# Thanks for you having read this notebook! :clap: :clap: :clap:
#
# ## SOURCES
#
#
# #### Other sources
# * YOLO original web site [Joseph Redmon Page](https://pjreddie.com/darknet/yolo/)
# * AlexeyAB darknet repo [github](https://github.com/AlexeyAB/darknet/)
# * The Ivan Goncharov [notebook](https://github.com/ivangrov/YOLOv3-GoogleColab/blob/master/YOLOv3_GoogleColab.ipynb) inspired me to try Google Colab and end up creating this notebook.
